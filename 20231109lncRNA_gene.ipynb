# %%
import pandas as pd
import pysam
import csv
import sys
import re
import collections
import scanpy as sc
import os
import glob

import pandas as pd
from pandas import Series
import glob
import plotly
import plotly.express as px  # import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
import matplotlib.pyplot as plt

import plotly.io as pio
#pio.templates.default = 'plotly_white'

# %%
import numpy as np

# %%
PATTERN = re.compile(r'(\S+?)\s*"(.*?)"')

# %%
    def get_properties_dict(properties_str):
        """
        allow no space after semicolon
        """
        
        if isinstance(properties_str, dict):
            return properties_str

        properties = collections.OrderedDict()
        attrs = properties_str.split(';')
        for attr in attrs:
            if attr:
                m = re.search(PATTERN, attr)
                if m:
                    key = m.group(1)
                    key = key.strip()
                    value = m.group(2)
                    value = value.strip()
                    properties[key] = value

        return properties

# %%
def gtf_reader_iter():
    with open("/SGRNJ06/randd/USER/cjj/filtered_ref/hs_ensembl_99/Homo_sapiens.GRCh38.99.gtf", mode='rt') as f:
        reader = csv.reader(f, delimiter='\t')
        for i, row in enumerate(reader, start=1):
            if len(row) == 0:
                continue
            if row[0].startswith('#'):
                yield row, True, None, None
                continue
            if len(row) != 9:
                sys.exit(f"Invalid number of columns in GTF line {i}: {row}\n")
            if row[6] not in ['+', '-']:
                sys.exit(f"Invalid strand in GTF line {i}: {row}\n")
            properties = get_properties_dict(row[8])
            annotation = row[2]
            if annotation == 'exon':
                if 'gene_id' not in properties:
                    raise GeneIdNotFound(f"Property 'gene_id' not found in GTF line {i}: {row}\n")
            yield row, False, annotation, properties

# %%
lncRNA_gene_set = set()
for _row, _is_comment, annotation, properties in gtf_reader_iter():
    if _is_comment:
        continue
    properties = dict(properties)
    if properties["gene_biotype"] == "lncRNA":
        gene_name = properties["gene_name"]
        lncRNA_gene_set.add(gene_name)
#     for key, value in properties.items():
#         if key == "gene_name":
#             gene_name = value
#         if value == "lncRNA":
#             lncRNA_gene_set.add(gene_name)

# %%
lncRNA_gene_set
# Out:
# True

# %%
dict(properties)
# Out:
# {'gene_id': 'ENSG00000268674',
#  'gene_version': '2',
#  'transcript_id': 'ENST00000601199',
#  'transcript_version': '2',
#  'exon_number': '1',
#  'gene_name': 'AC213203.1',
#  'gene_source': 'ensembl',
#  'gene_biotype': 'protein_coding',
#  'transcript_name': 'AC213203.1-201',
#  'transcript_source': 'ensembl',
#  'transcript_biotype': 'protein_coding',
#  'tag': 'basic',
#  'transcript_support_level': 'NA'}

# %%
len(lncRNA_gene_set)
# Out:
# 16877

# %%
out = open("/SGRNJ06/randd/USER/cjj/celedev/rna/lncRNA/20231212/lncRNA.txt", 'w')
for i in lncRNA_gene_set:
    out.write(f"{i}\n")
out.close()

# %%
matrix_file = "/SGRNJ06/randd/USER/cjj/celedev/rna/lncRNA/20230830/G61459"

# %%
adata = sc.read_10x_mtx(matrix_file,var_names='gene_symbols',)

# %%
sample = matrix_file.split('/')[-1]

# %%
adata.var_names
# Out:
# Index(['MIR1302-2HG', 'FAM138A', 'OR4F5', 'AL627309.1', 'AL627309.3',
#        'AL627309.2', 'AL627309.5', 'AL627309.4', 'AP006222.2', 'AL732372.1',
#        ...
#        'AC007325.2', 'BX072566.1', 'AL354822.1', 'AC023491.2', 'AC004556.3',
#        'AC233755.2', 'AC233755.1', 'AC240274.1', 'AC213203.4', 'AC213203.1'],
#       dtype='object', length=37493)

# %%
adata.var["lncRNA"] = adata.var_names.str.upper().isin(lncRNA_gene_set)

# %%
adata.var
# Out:
#                     gene_ids  lncRNA
# MIR1302-2HG  ENSG00000243485    True
# FAM138A      ENSG00000237613    True
# OR4F5        ENSG00000186092   False
# AL627309.1   ENSG00000238009    True
# AL627309.3   ENSG00000239945    True
# ...                      ...     ...
# AC233755.2   ENSG00000277856   False
# AC233755.1   ENSG00000275063   False
# AC240274.1   ENSG00000271254   False
# AC213203.4   ENSG00000277475   False
# AC213203.1   ENSG00000268674   False
#
# [37493 rows x 2 columns]

# %%
target = adata.var[adata.var["lncRNA"]==True]

# %%
target = set(target.index)

# %%
len(target)
# Out:
# 16815

# %%
df = adata.to_df()

# %%
df
# Out:
#                              MIR1302-2HG  FAM138A  OR4F5  AL627309.1  \
# AACACACAGAACGTCCAAGACCATCAA          0.0      0.0    0.0         0.0
# AACACACAGACCGTACTCGTCCTGGTA          0.0      0.0    0.0         0.0
# AACACACAGACGTTACGACTTAGCGAC          0.0      0.0    0.0         0.0
# AACACACAGAGCCACATATAGTAGAGC          0.0      0.0    0.0         0.0
# AACACACAGAGCCACATATGCTGCAGT          0.0      0.0    0.0         0.0
# ...                                  ...      ...    ...         ...
# TGTGGACACTGACTTCCGTTCAAGCTG          0.0      0.0    0.0         0.0
# TGTGGACACTGAGGCCTTCGTCAACTG          0.0      0.0    0.0         0.0
# TGTGGACACTGAGGCCTTGACCATCAA          0.0      0.0    0.0         0.0
# TGTGGACACTGGTAACCGGACGTAGAG          0.0      0.0    0.0         0.0
# TGTGGACACTGTCGGTGTCGACCTTAT          0.0      0.0    0.0         0.0
#
#                              AL627309.3  AL627309.2  AL627309.5  AL627309.4  \
# AACACACAGAACGTCCAAGACCATCAA         0.0         0.0         0.0         0.0
# AACACACAGACCGTACTCGTCCTGGTA         0.0         0.0         0.0         0.0
# AACACACAGACGTTACGACTTAGCGAC         0.0         0.0         0.0         0.0
# AACACACAGAGCCACATATAGTAGAGC         0.0         0.0         0.0         0.0
# AACACACAGAGCCACATATGCTGCAGT         0.0         0.0         0.0         0.0
# ...                                 ...         ...         ...         ...
# TGTGGACACTGACTTCCGTTCAAGCTG         0.0         0.0         0.0         0.0
# TGTGGACACTGAGGCCTTCGTCAACTG         0.0         0.0         0.0         0.0
# TGTGGACACTGAGGCCTTGACCATCAA         0.0         0.0         0.0         0.0
# TGTGGACACTGGTAACCGGACGTAGAG         0.0         0.0         0.0         0.0
# TGTGGACACTGTCGGTGTCGACCTTAT         0.0         0.0         0.0         0.0
#
#                              AP006222.2  AL732372.1  ...  AC007325.2  \
# AACACACAGAACGTCCAAGACCATCAA         0.0         0.0  ...         0.0
# AACACACAGACCGTACTCGTCCTGGTA         0.0         0.0  ...         0.0
# AACACACAGACGTTACGACTTAGCGAC         0.0         0.0  ...         0.0
# AACACACAGAGCCACATATAGTAGAGC         0.0         0.0  ...         0.0
# AACACACAGAGCCACATATGCTGCAGT         0.0         0.0  ...         0.0
# ...                                 ...         ...  ...         ...
# TGTGGACACTGACTTCCGTTCAAGCTG         0.0         0.0  ...         0.0
# TGTGGACACTGAGGCCTTCGTCAACTG         0.0         0.0  ...         0.0
# TGTGGACACTGAGGCCTTGACCATCAA         0.0         0.0  ...         0.0
# TGTGGACACTGGTAACCGGACGTAGAG         0.0         0.0  ...         0.0
# TGTGGACACTGTCGGTGTCGACCTTAT         0.0         0.0  ...         0.0
#
#                              BX072566.1  AL354822.1  AC023491.2  AC004556.3  \
# AACACACAGAACGTCCAAGACCATCAA         0.0         0.0         0.0         0.0
# AACACACAGACCGTACTCGTCCTGGTA         0.0         0.0         0.0         0.0
# AACACACAGACGTTACGACTTAGCGAC         0.0         0.0         0.0         0.0
# AACACACAGAGCCACATATAGTAGAGC         0.0         0.0         0.0         0.0
# AACACACAGAGCCACATATGCTGCAGT         0.0         0.0         0.0         0.0
# ...                                 ...         ...         ...         ...
# TGTGGACACTGACTTCCGTTCAAGCTG         0.0         0.0         0.0         0.0
# TGTGGACACTGAGGCCTTCGTCAACTG         0.0         0.0         0.0         0.0
# TGTGGACACTGAGGCCTTGACCATCAA         0.0         0.0         0.0         0.0
# TGTGGACACTGGTAACCGGACGTAGAG         0.0         0.0         0.0         4.0
# TGTGGACACTGTCGGTGTCGACCTTAT         0.0         0.0         0.0         0.0
#
#                              AC233755.2  AC233755.1  AC240274.1  AC213203.4  \
# AACACACAGAACGTCCAAGACCATCAA         0.0         0.0         0.0         0.0
# AACACACAGACCGTACTCGTCCTGGTA         0.0         0.0         0.0         0.0
# AACACACAGACGTTACGACTTAGCGAC         0.0         0.0         0.0         0.0
# AACACACAGAGCCACATATAGTAGAGC         0.0         0.0         0.0         0.0
# AACACACAGAGCCACATATGCTGCAGT         0.0         0.0         0.0         0.0
# ...                                 ...         ...         ...         ...
# TGTGGACACTGACTTCCGTTCAAGCTG         0.0         0.0         0.0         0.0
# TGTGGACACTGAGGCCTTCGTCAACTG         0.0         0.0         0.0         0.0
# TGTGGACACTGAGGCCTTGACCATCAA         0.0         0.0         0.0         0.0
# TGTGGACACTGGTAACCGGACGTAGAG         0.0         0.0         0.0         0.0
# TGTGGACACTGTCGGTGTCGACCTTAT         0.0         0.0         0.0         0.0
#
#                              AC213203.1
# AACACACAGAACGTCCAAGACCATCAA         0.0
# AACACACAGACCGTACTCGTCCTGGTA         0.0
# AACACACAGACGTTACGACTTAGCGAC         0.0
# AACACACAGAGCCACATATAGTAGAGC         0.0
# AACACACAGAGCCACATATGCTGCAGT         0.0
# ...                                 ...
# TGTGGACACTGACTTCCGTTCAAGCTG         0.0
# TGTGGACACTGAGGCCTTCGTCAACTG         0.0
# TGTGGACACTGAGGCCTTGACCATCAA         0.0
# TGTGGACACTGGTAACCGGACGTAGAG         0.0
# TGTGGACACTGTCGGTGTCGACCTTAT         0.0
#
# [4520 rows x 37493 columns]

# %%
df = df.loc[:, lambda d: d.columns.isin(target)]

# %%
df = df.replace(0, np.nan)
df = df.dropna(how='all', axis=0)
df = df.dropna(how='all', axis=1)
df = df.replace(np.nan, 0)

# %%
df.shape[1]
# Out:
# 7606

# %%
df.T
# Out:
#             AACACACAGAACGTCCAAGACCATCAA  AACACACAGACCGTACTCGTCCTGGTA  \
# AL627309.1                          0.0                          0.0
# AL627309.5                          0.0                          0.0
# AP006222.2                          0.0                          0.0
# LINC01409                           0.0                          0.0
# FAM87B                              0.0                          0.0
# ...                                 ...                          ...
# LINC01694                           0.0                          0.0
# AL133493.1                          0.0                          0.0
# AJ011931.2                          0.0                          0.0
# FTCD-AS1                            0.0                          0.0
# MCM3AP-AS1                          0.0                          0.0
#
#             AACACACAGACGTTACGACTTAGCGAC  AACACACAGAGCCACATATAGTAGAGC  \
# AL627309.1                          0.0                          0.0
# AL627309.5                          0.0                          0.0
# AP006222.2                          0.0                          0.0
# LINC01409                           0.0                          0.0
# FAM87B                              0.0                          0.0
# ...                                 ...                          ...
# LINC01694                           0.0                          0.0
# AL133493.1                          0.0                          0.0
# AJ011931.2                          0.0                          0.0
# FTCD-AS1                            0.0                          0.0
# MCM3AP-AS1                          0.0                          0.0
#
#             AACACACAGAGCCACATATGCTGCAGT  AACACACAGAGGCTGTTGGCACTATTC  \
# AL627309.1                          0.0                          0.0
# AL627309.5                          0.0                          0.0
# AP006222.2                          0.0                          0.0
# LINC01409                           0.0                          0.0
# FAM87B                              0.0                          0.0
# ...                                 ...                          ...
# LINC01694                           0.0                          0.0
# AL133493.1                          0.0                          0.0
# AJ011931.2                          0.0                          0.0
# FTCD-AS1                            0.0                          0.0
# MCM3AP-AS1                          0.0                          0.0
#
#             AACACACAGATACCAGTCAACAGGAAC  AACACACAGATACCAGTCACTGAAGCA  \
# AL627309.1                          0.0                          0.0
# AL627309.5                          0.0                          0.0
# AP006222.2                          0.0                          0.0
# LINC01409                           0.0                          0.0
# FAM87B                              0.0                          0.0
# ...                                 ...                          ...
# LINC01694                           0.0                          0.0
# AL133493.1                          0.0                          0.0
# AJ011931.2                          0.0                          0.0
# FTCD-AS1                            0.0                          0.0
# MCM3AP-AS1                          0.0                          0.0
#
#             AACACACAGATGCCTAAGTAGAGTCGC  AACACACAGATGTATCGGACGACGTAT  ...  \
# AL627309.1                          0.0                          0.0  ...
# AL627309.5                          0.0                          0.0  ...
# AP006222.2                          0.0                          0.0  ...
# LINC01409                           0.0                          0.0  ...
# FAM87B                              0.0                          0.0  ...
# ...                                 ...                          ...  ...
# LINC01694                           0.0                          0.0  ...
# AL133493.1                          0.0                          0.0  ...
# AJ011931.2                          0.0                          0.0  ...
# FTCD-AS1                            0.0                          0.0  ...
# MCM3AP-AS1                          0.0                          0.0  ...
#
#             TGTGGACACTACTCACCATGCTGCAGT  TGTGGACACTATCGTGCACTAGGTTGC  \
# AL627309.1                          0.0                          0.0
# AL627309.5                          0.0                          0.0
# AP006222.2                          0.0                          0.0
# LINC01409                           0.0                          0.0
# FAM87B                              0.0                          0.0
# ...                                 ...                          ...
# LINC01694                           0.0                          0.0
# AL133493.1                          0.0                          0.0
# AJ011931.2                          0.0                          0.0
# FTCD-AS1                            0.0                          0.0
# MCM3AP-AS1                          0.0                          0.0
#
#             TGTGGACACTCCTGGCTTTATGCTCTC  TGTGGACACTCTTCTCAGCAAGGTGTT  \
# AL627309.1                          0.0                          0.0
# AL627309.5                          0.0                          0.0
# AP006222.2                          0.0                          0.0
# LINC01409                           0.0                          0.0
# FAM87B                              0.0                          0.0
# ...                                 ...                          ...
# LINC01694                           0.0                          0.0
# AL133493.1                          0.0                          0.0
# AJ011931.2                          0.0                          0.0
# FTCD-AS1                            0.0                          0.0
# MCM3AP-AS1                          0.0                          0.0
#
#             TGTGGACACTCTTCTCAGTAGAGTCGC  TGTGGACACTGACTTCCGTTCAAGCTG  \
# AL627309.1                          0.0                          0.0
# AL627309.5                          0.0                          0.0
# AP006222.2                          0.0                          0.0
# LINC01409                           0.0                          0.0
# FAM87B                              0.0                          0.0
# ...                                 ...                          ...
# LINC01694                           0.0                          0.0
# AL133493.1                          0.0                          0.0
# AJ011931.2                          0.0                          0.0
# FTCD-AS1                            0.0                          0.0
# MCM3AP-AS1                          0.0                          0.0
#
#             TGTGGACACTGAGGCCTTCGTCAACTG  TGTGGACACTGAGGCCTTGACCATCAA  \
# AL627309.1                          0.0                          0.0
# AL627309.5                          0.0                          0.0
# AP006222.2                          0.0                          0.0
# LINC01409                           0.0                          0.0
# FAM87B                              0.0                          0.0
# ...                                 ...                          ...
# LINC01694                           0.0                          0.0
# AL133493.1                          0.0                          0.0
# AJ011931.2                          0.0                          0.0
# FTCD-AS1                            0.0                          0.0
# MCM3AP-AS1                          0.0                          0.0
#
#             TGTGGACACTGGTAACCGGACGTAGAG  TGTGGACACTGTCGGTGTCGACCTTAT
# AL627309.1                          0.0                          0.0
# AL627309.5                          0.0                          0.0
# AP006222.2                          0.0                          0.0
# LINC01409                           0.0                          0.0
# FAM87B                              0.0                          0.0
# ...                                 ...                          ...
# LINC01694                           0.0                          0.0
# AL133493.1                          0.0                          0.0
# AJ011931.2                          0.0                          0.0
# FTCD-AS1                            0.0                          0.0
# MCM3AP-AS1                          0.0                          0.0
#
# [7606 rows x 4519 columns]

# %%
    df1 = df.T
    bc_set  = (set(df1.columns))
    result = []
    for bc in bc_set:
        result.append(total_lncRNA_gene - df1[bc].value_counts()[0])
    gene_per_cell.append(np.median(result))

# %%
matrix_files = os.listdir("/SGRNJ06/randd/USER/cjj/celedev/rna/lncRNA/20231206/count")

# %%
matrix_files = [f"/SGRNJ06/randd/USER/cjj/celedev/rna/lncRNA/20231206/count/{i}" for i in matrix_files]

# %%
matrix_files = [i for i in matrix_files if os.path.isdir(i)]

# %%
matrix_files
# Out:
# ['/SGRNJ06/randd/USER/cjj/celedev/rna/lncRNA/20231206/count/CR961431',
#  '/SGRNJ06/randd/USER/cjj/celedev/rna/lncRNA/20231206/count/CL961431']

# %%
sample_list = []
total_lncRNA = []
gene_per_cell = []
for matrix_file in matrix_files:
    adata = sc.read_10x_mtx(matrix_file,var_names='gene_symbols',)
    sample = matrix_file.split('/')[-1]
    sample_list.append(sample)
    
    adata.var["lncRNA"] = adata.var_names.str.upper().isin(lncRNA_gene_set)
    target = adata.var[adata.var["lncRNA"]==True]
    target = set(target.index)
    df = adata.to_df()
    df = df.loc[:, lambda d: d.columns.isin(target)]
    df = df.replace(0, np.nan)
    df = df.dropna(how='all', axis=0)
    df = df.dropna(how='all', axis=1)
    df = df.replace(np.nan, 0)
    
    total_lncRNA_gene = df.shape[1]
    total_lncRNA.append(total_lncRNA_gene)
    
    
    df1 = df.T
    bc_set  = (set(df1.columns))
    result = []
    for bc in bc_set:
        result.append(total_lncRNA_gene - df1[bc].value_counts()[0])
    gene_per_cell.append(np.median(result))

# %%
sample_list
# Out:
# ['CR961431', 'CL961431']

# %%
total_lncRNA
# Out:
# [11447, 10674]

# %%
gene_per_cell
# Out:
# [55.0, 55.0]

# %%
adata = sc.read_h5ad("/SGRNJ06/randd/USER/cjj/celedev/rna/20231108/LPMFTBC231027012/04.analysis/LPMFTBC231027012.h5ad")

# %%
adata.obs.value_counts('cluster')
