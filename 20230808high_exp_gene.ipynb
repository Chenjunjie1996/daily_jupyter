# %%
import pandas as pd 
import scanpy as sc
import glob

# %%
/SGRNJ06/randd/PROJECT/RD21010602_GEXSCOPE_V3/20230725/
/SGRNJ06/randd/PROJECT/RD21010602_GEXSCOPE_V3/20230704_cycle/

# %%
glob.glob("/SGRNJ06/randd/PROJECT/RD21010602_GEXSCOPE_V3/20230704_cycle/*/06*/*.h5ad")
# Out:
# ['/SGRNJ06/randd/PROJECT/RD21010602_GEXSCOPE_V3/20230704_cycle/HK562_0628_tdt_5cycle/06.analysis/HK562_0628_tdt_5cycle.h5ad',
#  '/SGRNJ06/randd/PROJECT/RD21010602_GEXSCOPE_V3/20230704_cycle/HK562_0628_tdt_7cycle/06.analysis/HK562_0628_tdt_7cycle.h5ad',
#  '/SGRNJ06/randd/PROJECT/RD21010602_GEXSCOPE_V3/20230704_cycle/HK562_0628_tdt_4cycle/06.analysis/HK562_0628_tdt_4cycle.h5ad',
#  '/SGRNJ06/randd/PROJECT/RD21010602_GEXSCOPE_V3/20230704_cycle/HK562_0628_tdt_6cycle/06.analysis/HK562_0628_tdt_6cycle.h5ad']

# %%
adata = sc.read_h5ad("/SGRNJ06/randd/PROJECT/RD21010602_GEXSCOPE_V3/20230704_cycle/HK562_0628_tdt_6cycle/06.analysis/HK562_0628_tdt_6cycle.h5ad")

# %%
adata.var_names_make_unique()

# %%
adata.var
# Out:
#                     gene_ids   mito  n_cells_by_counts  mean_counts  \
# DDX11L1      ENSG00000223972  False                  0     0.000000
# WASH7P       ENSG00000227232  False                 64     0.039013
# MIR6859-1    ENSG00000278267  False                  0     0.000000
# MIR1302-2HG  ENSG00000243485  False                  6     0.003442
# MIR1302-2    ENSG00000284332  False                  0     0.000000
# ...                      ...    ...                ...          ...
# AC240274.1   ENSG00000271254  False                 10     0.005737
# AC213203.2   ENSG00000275405  False                  0     0.000000
# AC213203.3   ENSG00000275987  False                  1     0.000574
# AC213203.4   ENSG00000277475  False                  0     0.000000
# AC213203.1   ENSG00000268674  False                  0     0.000000
#
#              pct_dropout_by_counts  total_counts  highly_variable  \
# DDX11L1                 100.000000           0.0            False
# ...

# %%
adata.var.sort_values("mean_counts", ascending=False).head(20)
# Out:
#                 gene_ids   mito  n_cells_by_counts  mean_counts  \
# MT-CO3   ENSG00000198938   True               1743   143.940338
# MT-CO2   ENSG00000198712   True               1743    84.796326
# FTL      ENSG00000087086  False               1743    84.035568
# MT-CO1   ENSG00000198804   True               1743    72.318993
# HBA1     ENSG00000206172  False               1743    66.115318
# FTH1     ENSG00000167996  False               1743    56.893860
# RPLP1    ENSG00000137818  False               1743    51.534710
# RPS2     ENSG00000140988  False               1743    51.451519
# MT-ND2   ENSG00000198763   True               1743    45.293171
# MT-ATP6  ENSG00000198899   True               1743    42.932301
# RPL32    ENSG00000144713  False               1743    41.438324
# RPS18    ENSG00000231500  False               1743    40.290878
# RPLP2    ENSG00000177600  False               1743    37.799770
# MT-ND4   ENSG00000198886   True               1743    37.795753
# ...

# %%
adata.var.sort_values("mean_counts", ascending=False).head(20).to_csv("/SGRNJ06/randd/USER/cjj/celedev/rna/20230808high_exp_gene/HK562_0628_tdt_6cycle.tsv", sep='\t')

# %%
adata = sc.read_10x_mtx("/SGRNJ06/randd/PROJECT/RD21010602_GEXSCOPE_V3/20230704_cycle/HK562_0628_tdt_7cycle/05.count/HK562_0628_tdt_7cycle_filtered_feature_bc_matrix/", var_names="gene_symbols")

# %%
adata.var_names_make_unique()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2034 × 60676
#     var: 'gene_ids'

# %%
sc.pl.highest_expr_genes(adata, n_top=20)

# %%
adata.var
# Out:
#                     gene_ids
# DDX11L1      ENSG00000223972
# WASH7P       ENSG00000227232
# MIR6859-1    ENSG00000278267
# MIR1302-2HG  ENSG00000243485
# MIR1302-2    ENSG00000284332
# ...                      ...
# AC240274.1   ENSG00000271254
# AC213203.2   ENSG00000275405
# AC213203.3   ENSG00000275987
# AC213203.4   ENSG00000277475
# AC213203.1   ENSG00000268674
#
# [60676 rows x 1 columns]
