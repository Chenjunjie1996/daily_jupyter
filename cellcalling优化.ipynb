# %%
import scanpy as sc
import numpy as np
import pandas as pd
import math

from celescope.tools import utils
from celescope.__init__ import HELP_DICT
from celescope.rna.mkref import Mkref_rna
from celescope.tools.step import Step, s_common

# %%
sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.settings.set_figure_params(dpi=80, facecolor='white')

# %%
adata = sc.read('/SGRNJ06/randd/USER/cjj/celedev/vdj10x/20220803/c3rna/LC38CA/06.analysis/LC38CA.h5ad')

# %%
adata

# %%
adata.var.sort_values(by='total_counts',ascending=False)

# %%
def find_anomalies(data_list):
    anomalies = []
    # set upper limit
    data_std = np.std(data_list)
    data_mean = np.mean(data_list)
    anomaly_cut_off = data_std * 3
    
    upper_limit = data_mean + data_std * 3
    print(upper_limit)
    
    # Generate outliers
    for outlier in data_list:
        if outlier > upper_limit:
            anomalies.append(outlier)
    return anomalies

# %%
data_list = adata.var.sort_values(by='total_counts',ascending=False).total_counts.tolist()

# %%
anomalies=find_anomalies(data_list)
# Out:
# 109890.24291829795

# %%
anomalies

# %%
count_file = pd.read_csv('/SGRNJ06/randd/USER/cjj/TESTDATA/test_rna/20220708crmixed/220417014/05.count/220417014_count_detail.txt',sep='\t')

# %%
count_file

# %%
count_file['total_counts'] = count_file.groupby('geneID')['count'].transform('sum')

# %%
count_file.sort_values('total_counts',ascending=False, inplace=True)

# %%
df_for_calling = count_file

# %%
df_for_calling

# %%
        df_for_calling['total_counts'] = df_for_calling.groupby('geneID')['count'].transform('sum')
        df_for_calling.sort_values('total_counts', ascending=False, inplace=True)

        # upper limit
        data_std = np.std(df_for_calling.total_counts)
        data_mean = np.mean(df_for_calling.total_counts)
        upper_limit = data_mean + data_std * 3

# %%
upper_limit
# Out:
# 36778911.06755154

# %%
df_for_calling = df_for_calling[df_for_calling['total_counts'].apply(lambda x: x <= upper_limit)]

# %%
df_for_calling

# %%
del df_for_calling['total_counts']

# %%
df_for_calling

# %%
import copy
import sys

# %%
        df = pd.read_table('/SGRNJ06/randd/USER/cjj/celedev/vdj10x/20220803/c3rna/LC38CA/05.count/LC38CA_count_detail.txt', header=0)

# %%
        df['total_counts'] = df.groupby('geneID')['count'].transform('sum')
        df.sort_values('total_counts', ascending=False, inplace=True)

        # upper limit
        data_std = np.std(df.drop_duplicates('geneID').total_counts)
        data_mean = np.mean(df.drop_duplicates('geneID').total_counts)

# %%
        upper_limit = data_mean + data_std * 3

# %%
        upper_limit
# Out:
# 357863.7320139976

# %%
        df.drop_duplicates('geneID')

# %%
        # delete outliers and get high-exp genes
        df_for_calling = df[df['total_counts'].apply(lambda x: x <= upper_limit)]
        df_high_exp = df[df['total_counts'].apply(lambda x: x > upper_limit)]

# %%
        del df_for_calling['total_counts']

# %%
    def pre_calling(df, coef=6):
        """
        Three-Sigma Limits. Three sigma can determine if any outliers exist in a data set when evaluating collected variables.
        Delete anomaly high-expressed genes for cell_calling.
        Args:
            df_for_calling: count detail file.
            coef: use for calculating upper_limit.
        Returns:
            df_for_calling where anomaly high-expressed genes have been deleted.
        """
        df = df.copy()
        df['total_counts'] = df.groupby('geneID')['count'].transform('sum')
        df.sort_values('total_counts', ascending=False, inplace=True)

        # upper limit
        data_std = np.std(df.drop_duplicates('geneID').total_counts)
        data_mean = np.mean(df.drop_duplicates('geneID').total_counts)
        upper_limit = data_mean + data_std * coef

        # delete outliers and get high-exp genes
        df_for_calling = df[df['total_counts'].apply(lambda x: x <= upper_limit)]
        df_high_exp = df[df['total_counts'].apply(lambda x: x > upper_limit)]
        del df_for_calling['total_counts']

        return df_for_calling, df_high_exp

# %%
        df = pd.read_table('/SGRNJ06/randd/USER/cjj/celedev/cell_calling/20220826auto_compare/Clu-mes/05.count/Clu-mes_count_detail.txt', header=0)

# %%
        df

# %%
        df_for_calling, df_high_exp = pre_calling(df)

# %%
        df_for_calling
# Out:
#                               Barcode              geneID           UMI  count
# 5817121   ACATCGGACCTCCTCAATTGCTGCAGT  ENSMUSG00000098178  CCACGCCCCCGG      3
# 66679639  TGTAGTGTGCGTCATACCGGCCATGTT  ENSMUSG00000098178  CGAATGCGCCCA      4
# 31935779  CTGGTACTTACACCAACGCCATATCTC  ENSMUSG00000098178  TTTCACCCTGGC     12
# 42356964  GCGAGTAACAACGTCCAATCGAACTCC  ENSMUSG00000098178  ATACCCTTGAGA      1
# 31684701  CTCAGAACTGTATCCTTCCTATGACCA  ENSMUSG00000098178  TACAATCTACAC      2
# ...                               ...                 ...           ...    ...
# 42720395  GCGAGTAACGCTGCGATAGTCTCGAAG  ENSMUSG00000113086  GCAGTCCCGGTT      1
# 32868423  CTTACGCAGCTGTGGTATGACATGGCT  ENSMUSG00000115507  CGGGTAAGCGCC      1
# 768035    AACACCGTTAACGTCCAAACTGGTTCC  ENSMUSG00000065604  CTTTGTAACCGC      1
# 21218890  CAGTCTTCGAACGTCCAAGACTATTCC  ENSMUSG00000065836  TCCTCGAGTGTT      1
# 34045745  GAACGCTATACGTTACGATAAGAGCGT  ENSMUSG00000112371  GTCCGCGAGACG      1
#
# [38379764 rows x 4 columns]

# %%
        df_high_exp
# Out:
#                               Barcode              geneID           UMI  \
# 0         AACACACAGAACACACAGGTGGCAACT  ENSMUSG00000052305  ATCAGAAACCGG
# 58948068  TCGGTTCGTCACTAGGCACACACCTCA  ENSMUSG00000052305  GACTCCGCATTT
# 44152781  GCTCTCACTGCAACTTCACCGAGATGT  ENSMUSG00000052305  GCAACCGTGGGT
# 44152782  GCTCTCACTGCAACTTCACCGAGATGT  ENSMUSG00000052305  GCAAGATTATCC
# 44152783  GCTCTCACTGCAACTTCACCGAGATGT  ENSMUSG00000052305  GCAAGCACGTTT
# ...                               ...                 ...           ...
# 62563085  TGCATCAAGTAGCGATGAGTCTCGAAG  ENSMUSG00000002985  ATGCGGCTGCGA
# 62563084  TGCATCAAGTAGCGATGAGTCTCGAAG  ENSMUSG00000002985  ATCGAGCGTAGT
# 7072629   ACGAATGGAACCTCGACTAGTGCTACA  ENSMUSG00000002985  GTGCCCGTTATA
# 39839570  GATGTTACGGGTGATCAGCCATATCTC  ENSMUSG00000002985  TCCGTTATCATC
# 29142715  CGGTGATTGCACTAGGCATTAGCATCC  ENSMUSG00000002985  AAGTAGGGTGTT
#
#           count  total_counts
# 0             1      35016187
# 58948068      1      35016187
# 44152781      2      35016187
# 44152782      3      35016187
# 44152783      1      35016187
# ...         ...           ...
# 62563085      1       2290550
# 62563084      1       2290550
# 7072629       1       2290550
# 39839570      3       2290550
# 29142715      3       2290550
#
# [30065872 rows x 5 columns]

# %%
        df
# Out:
#                               Barcode              geneID           UMI  count
# 0         AACACACAGAACACACAGGTGGCAACT  ENSMUSG00000052305  ATCAGAAACCGG      1
# 1         AACACACAGAACGCTAGTAACAAGTGG  ENSMUSG00000069919  ATCTCTGATTGT      1
# 2         AACACACAGAACGCTAGTAACAAGTGG  ENSMUSG00000069919  TAAATCTAGCCA      1
# 3         AACACACAGAACGCTAGTAACAAGTGG  ENSMUSG00000069919  TTGGCAAGTGGC      3
# 4         AACACACAGAACGCTAGTAACAAGTGG  ENSMUSG00000052305  CAAGAGCTATAA      1
# ...                               ...                 ...           ...    ...
# 68445631  TTCCAATCGGATCAGGACCAAGAGTAG  ENSMUSG00000091269  AAAGCACGCTAA      1
# 68445632  TTGGTGACCAAGGTGGTAACTCGGATT  ENSMUSG00000006360  CCTGCGGTAATT      9
# 68445633  TTGGTGACCCCATAATCGAACAGGAAC  ENSMUSG00000069919  TTTTGTCCCTGT      2
# 68445634  TTGGTGACCTTACACGACCCAATTGGC  ENSMUSG00000069919  AAAGTCCTATCA      9
# 68445635  TTGTGTACGACAACAGGTCTCTGCTTA  ENSMUSG00000032484  GTCCAAAGCGTT      1
#
# [68445636 rows x 4 columns]

# %%
df_high_exp.geneID.unique()
# Out:
# array(['ENSMUSG00000052305', 'ENSMUSG00000069919', 'ENSMUSG00000069917',
#        'ENSMUSG00000073940', 'ENSMUSG00000076609', 'ENSMUSG00000064339',
#        'ENSMUSG00000002985'], dtype=object)

# %%
df_high_exp.drop_duplicates('geneID')
# Out:
#                               Barcode              geneID           UMI  \
# 0         AACACACAGAACACACAGGTGGCAACT  ENSMUSG00000052305  ATCAGAAACCGG
# 1216119   AACACCGTTGGCATGCAATGGCAATTC  ENSMUSG00000069919  GCTGAATTTGAC
# 22613813  CCAATGTCTCATACGACCGACATGGCT  ENSMUSG00000069917  GCCGTGAATGTG
# 45533651  GGATACCACCTGTGGTATACGTGTGTT  ENSMUSG00000073940  TCCATGTACAAC
# 18430113  CACCTGTAAAGGCTGTTGGAACCTGTA  ENSMUSG00000076609  GAGCGTTCACGG
# 11377868  AGGAGCAATCCTACAAGGCCATATCTC  ENSMUSG00000064339  TAAGCCAAGTTT
# 2527710   AACTGGCGACGTCATACCTCCAGTTAG  ENSMUSG00000002985  AGACGATGGCAC
#
#           count  total_counts
# 0             1      35016187
# 1216119       3      33818268
# 22613813      5      23991231
# 45533651      1       6818469
# 18430113      1       3080977
# 11377868      5       3080459
# 2527710       4       2290550

# %%
        df1 = pd.read_table('/SGRNJ06/randd/USER/cjj/celedev/vdj10x/20220803/c3rna/LC38CA/05.count/LC38CA_count_detail.txt', header=0)

# %%
        df1
# Out:
#                             Barcode           geneID        UMI  count
# 0          AAACATCGAAACATCGAAACATCG  ENSG00000204287  AAGGCATTC      1
# 1          AAACATCGAAACATCGAAACATCG  ENSG00000204592  ACGTAGGGT      1
# 2          AAACATCGAAACATCGAAACATCG  ENSG00000198712  AGAGCGCCG      1
# 3          AAACATCGAAACATCGAAACATCG  ENSG00000198712  TGGGTTGTT      1
# 4          AAACATCGAAACATCGAAACATCG  ENSG00000158874  AGGAGAGAT      1
# ...                             ...              ...        ...    ...
# 142541468  TTCACGCATTCACGCATTCACGCA  ENSG00000170315  TATTTGGCA      1
# 142541469  TTCACGCATTCACGCATTCACGCA  ENSG00000149806  TCCGCATAC      1
# 142541470  TTCACGCATTCACGCATTCACGCA  ENSG00000158874  TCTGGGGTA      1
# 142541471  TTCACGCATTCACGCATTCACGCA  ENSG00000177954  TGTATGGCT      1
# 142541472  TTCACGCATTCACGCATTCACGCA  ENSG00000105559  TTCGGTCGG      1
#
# [142541473 rows x 4 columns]

# %%
        df_for_calling1, df_high_exp1 = pre_calling(df1)

# %%
        df_for_calling1
# Out:
#                             Barcode           geneID        UMI  count
# 83072316   CCTCCTGATCCGTCTACCAGTTCA  ENSG00000071082  GAGAGTTAA      1
# 132937339  TCCGTCTAACACAGAATTCACGCA  ENSG00000071082  TACCAACTC      6
# 11181631   AAGAGATCCTCAATGACTCAATGA  ENSG00000071082  TTTCACGAG      4
# 46671027   AGTCACTAACGTATCAAGCAGGAA  ENSG00000071082  GGGAGCTGT      1
# 17234045   AATGTTGCCTGGCATAGCCAAGAC  ENSG00000071082  GCCAAAATA      3
# ...                             ...              ...        ...    ...
# 32684777   ACTATGCAAACAACCACAAGGAGC  ENSG00000212145  AAAGCATCG      1
# 106314214  GACTAGTATGGAACAAGAATCTGA  ENSG00000243064  GGGGACTCC      1
# 59884473   CAAGACTAACAGCAGAGTGTTCTA  ENSG00000233778  GGGCTCGTA      1
# 103546682  GACAGTGCAGAGTCAAAAGAGATC  ENSG00000214797  ACGACGACT      1
# 22296637   ACACGACCTGGTGGTACCTCTATC  ENSG00000255265  CAGCGTGTC      1
#
# [96282353 rows x 4 columns]

# %%
        df_high_exp1
# Out:
#                             Barcode           geneID        UMI  count  \
# 67513841   CAGATCTGACTATGCAGAACAGGC  ENSG00000158874  TAGCGAGCC      1
# 27142194   ACCACTGTAGCCATGCCCTCTATC  ENSG00000158874  CTGTGGCAT      1
# 27142200   ACCACTGTAGCCATGCCCTCTATC  ENSG00000158874  GACGGAACC      3
# 27142199   ACCACTGTAGCCATGCCCTCTATC  ENSG00000158874  GAATGGCGT      2
# 90301467   CGCATACATCCGTCTAACCACTGT  ENSG00000158874  AAGAGAGTC      1
# ...                             ...              ...        ...    ...
# 19638641   ACACAGAAAGCCATGCGAGTTAGC  ENSG00000106927  CATACGGTG      7
# 25089821   ACAGCAGAGATAGACAACAGCAGA  ENSG00000106927  ACTTACGTA      1
# 109655201  GAGTTAGCTGGAACAAACATTGGC  ENSG00000106927  TTCCACGCG      1
# 97284472   CTGGCATAAAGACGGAGTCTGTCA  ENSG00000106927  TGTCCGCGA      1
# 63482555   CAATGGAACCATCCTCAACCGAGA  ENSG00000106927  GGTAATCCA      1
#
#            total_counts
# 67513841       14617744
# 27142194       14617744
# 27142200       14617744
# 27142199       14617744
# 90301467       14617744
# ...                 ...
# 19638641         709227
# 25089821         709227
# 109655201        709227
# 97284472         709227
# 63482555         709227
#
# [46259120 rows x 5 columns]

# %%
        df1
# Out:
#                             Barcode           geneID        UMI  count
# 0          AAACATCGAAACATCGAAACATCG  ENSG00000204287  AAGGCATTC      1
# 1          AAACATCGAAACATCGAAACATCG  ENSG00000204592  ACGTAGGGT      1
# 2          AAACATCGAAACATCGAAACATCG  ENSG00000198712  AGAGCGCCG      1
# 3          AAACATCGAAACATCGAAACATCG  ENSG00000198712  TGGGTTGTT      1
# 4          AAACATCGAAACATCGAAACATCG  ENSG00000158874  AGGAGAGAT      1
# ...                             ...              ...        ...    ...
# 142541468  TTCACGCATTCACGCATTCACGCA  ENSG00000170315  TATTTGGCA      1
# 142541469  TTCACGCATTCACGCATTCACGCA  ENSG00000149806  TCCGCATAC      1
# 142541470  TTCACGCATTCACGCATTCACGCA  ENSG00000158874  TCTGGGGTA      1
# 142541471  TTCACGCATTCACGCATTCACGCA  ENSG00000177954  TGTATGGCT      1
# 142541472  TTCACGCATTCACGCATTCACGCA  ENSG00000105559  TTCGGTCGG      1
#
# [142541473 rows x 4 columns]

# %%
df_high_exp1.geneID.unique()
# Out:
# array(['ENSG00000158874', 'ENSG00000198804', 'ENSG00000251562',
#        'ENSG00000087086', 'ENSG00000198938', 'ENSG00000166710',
#        'ENSG00000198727', 'ENSG00000198899', 'ENSG00000198712',
#        'ENSG00000198886', 'ENSG00000210082', 'ENSG00000211459',
#        'ENSG00000019582', 'ENSG00000198763', 'ENSG00000118271',
#        'ENSG00000167996', 'ENSG00000205542', 'ENSG00000198786',
#        'ENSG00000163631', 'ENSG00000075624', 'ENSG00000130208',
#        'ENSG00000177954', 'ENSG00000101439', 'ENSG00000204287',
#        'ENSG00000137818', 'ENSG00000198888', 'ENSG00000198840',
#        'ENSG00000130203', 'ENSG00000034510', 'ENSG00000211592',
#        'ENSG00000187514', 'ENSG00000106927'], dtype=object)

# %%
df_high_exp1.drop_duplicates('geneID')
# Out:
#                             Barcode           geneID        UMI  count  \
# 67513841   CAGATCTGACTATGCAGAACAGGC  ENSG00000158874  TAGCGAGCC      1
# 43512018   AGCCATGCTCTTCACACAAGGAGC  ENSG00000198804  AACAGGTCT      1
# 67442294   CAGATCTGACATTGGCAGATCGCA  ENSG00000251562  ATAGTGTTA      1
# 139300874  TGGCTTCACCGTGAGAACAGCAGA  ENSG00000087086  AATGTACCC      3
# 102746794  GAATCTGAGACAGTGCAAGGACAC  ENSG00000198938  CAGGCGTGT      1
# 36565608   AGATCGCACGAACTTACGACACAC  ENSG00000166710  TGGTCCCGT      1
# 111560566  GATGAATCAAGGACACTAGGATGA  ENSG00000198727  TTCTGGCCA      2
# 25029058   ACAGCAGAGACTAGTACCAGTTCA  ENSG00000198899  GATAGCGTG      1
# 104170153  GACAGTGCCGACTGGAAGGCTAAC  ENSG00000198712  CTGTTGAGC      1
# 115435881  GCCACATACCTCCTGACATACCAA  ENSG00000198886  TAGAGCTGG      3
# 142435311  TTCACGCATCCGTCTATATCAGCA  ENSG00000210082  GTGACCTAC      1
# 17786819   ACAAGCTAAAGGTACAGCCACATA  ENSG00000211459  ATCGTGAGC      3
# 52347101   ATCCTGTAAACGTGATCCATCCTC  ENSG00000019582  CGGGTGATT      3
# 81906165   CCTCCTGAAGATCGCAAGTACAAG  ENSG00000198763  CAGTGGTGC      3
# 24938256   ACAGCAGACTGTAGCCAGTGGTCA  ENSG00000118271  ATTGAAATA      3
# 50986003   ATCATTCCAACTCACCAGGCTAAC  ENSG00000167996  GGCTGAGTT      1
# 117048637  GCGAGTAACGAACTTATGGAACAA  ENSG00000205542  CGGAGGCTA      3
# 42466546   AGCCATGCACAGATTCGCCAAGAC  ENSG00000198786  CACGATATG      1
# 40127052   AGCACCTCGTGTTCTACTAAGGTC  ENSG00000163631  GACTGGCGC      3
# 42459847   AGCCATGCACAGATTCCAAGACTA  ENSG00000075624  TGTAGGACT      1
# 32216267   ACGTATCAGAACAGGCGCTCGGTA  ENSG00000130208  CAAGGTAGA      2
# 73918716   CCAGTTCAGTACGCAAAGATCGCA  ENSG00000177954  CTGACCATA      1
# 97994505   CTGGCATACTAAGGTCCTGAGCCA  ENSG00000101439  TCCGAAATC      3
# 33304690   ACTATGCACAATGGAACTCAATGA  ENSG00000204287  ACGGTAGAG      2
# 23628164   ACAGATTCTCTTCACACCTAATCC  ENSG00000137818  CTCCGCGCG      2
# 71020853   CATACCAACGACACACGAGTTAGC  ENSG00000198888  GCGATTCGG      1
# 85274379   CGAACTTACAGCGTTAACAAGCTA  ENSG00000198840  AGGGTGCTC      1
# 92319057   CGGATTGCCAGATCTGAGCACCTC  ENSG00000130203  CAGCAAGAT      3
# 66772279   CACTTCGAGACAGTGCAACAACCA  ENSG00000034510  TGCCGCTGT      2
# 71003943   CATACCAACGAACTTAGCCACATA  ENSG00000211592  GTAGTCGGA      2
# 76850319   CCGAAGTAGAATCTGAGAGTTAGC  ENSG00000187514  CAGTACAAC      2
# 17816648   ACAAGCTAAATGTTGCACTATGCA  ENSG00000106927  TAAAGTTGA      1
#
#            total_counts
# 67513841       14617744
# 43512018        7077833
# 67442294        5801404
# 139300874       5097303
# 102746794       4620966
# 36565608        4270788
# 111560566       3590443
# 25029058        3273124
# 104170153       3179381
# 115435881       3166008
# 142435311       3100712
# 17786819        2803184
# 52347101        2362304
# 81906165        1809173
# 24938256        1653060
# 50986003        1499015
# 117048637       1445587
# 42466546        1393609
# 40127052        1383496
# 42459847        1162408
# 32216267        1149728
# 73918716        1130772
# 97994505        1112197
# 33304690        1063543
# 23628164        1053379
# 71020853        1052906
# 85274379        1043345
# 92319057         947928
# 66772279         923829
# 71003943         779484
# 76850319         764134
# 17816648         709227

# %%
df_high_exp.drop_duplicates('geneID')
# Out:
#                               Barcode              geneID           UMI  \
# 0         AACACACAGAACACACAGGTGGCAACT  ENSMUSG00000052305  ATCAGAAACCGG
# 1216119   AACACCGTTGGCATGCAATGGCAATTC  ENSMUSG00000069919  GCTGAATTTGAC
# 22613813  CCAATGTCTCATACGACCGACATGGCT  ENSMUSG00000069917  GCCGTGAATGTG
# 45533651  GGATACCACCTGTGGTATACGTGTGTT  ENSMUSG00000073940  TCCATGTACAAC
# 18430113  CACCTGTAAAGGCTGTTGGAACCTGTA  ENSMUSG00000076609  GAGCGTTCACGG
# 11377868  AGGAGCAATCCTACAAGGCCATATCTC  ENSMUSG00000064339  TAAGCCAAGTTT
# 2527710   AACTGGCGACGTCATACCTCCAGTTAG  ENSMUSG00000002985  AGACGATGGCAC
#
#           count  total_counts
# 0             1      35016187
# 1216119       3      33818268
# 22613813      5      23991231
# 45533651      1       6818469
# 18430113      1       3080977
# 11377868      5       3080459
# 2527710       4       2290550

# %%
alist = df_high_exp.drop_duplicates('geneID').total_counts.tolist()
alist1 = df_high_exp1.drop_duplicates('geneID').total_counts.tolist()

# %%
alist
# Out:
# [35016187, 33818268, 23991231, 6818469, 3080977, 3080459, 2290550]

# %%
alist1

# %%
np.median(alist)
# Out:
# 6818469.0

# %%
np.median(alist1)
# Out:
# 1472301.0

# %%
from sklearn import preprocessing

# %%
df_temp = df.copy()

# %%
df_temp

# %%
        df_temp['total_counts'] = df_temp.groupby('geneID')['count'].transform('sum')
        df_temp.sort_values('total_counts', ascending=False, inplace=True)

# %%
        data_std = np.std(df_temp.drop_duplicates('geneID').total_counts)
        data_mean = np.mean(df_temp.drop_duplicates('geneID').total_counts)

# %%
        df_temp['zscore'] = df_temp['total_counts'].apply(lambda x: (x-data_mean)/data_std)

# %%
        df_temp
# Out:
#                               Barcode              geneID           UMI  \
# 0         AACACACAGAACACACAGGTGGCAACT  ENSMUSG00000052305  ATCAGAAACCGG
# 58948068  TCGGTTCGTCACTAGGCACACACCTCA  ENSMUSG00000052305  GACTCCGCATTT
# 44152781  GCTCTCACTGCAACTTCACCGAGATGT  ENSMUSG00000052305  GCAACCGTGGGT
# 44152782  GCTCTCACTGCAACTTCACCGAGATGT  ENSMUSG00000052305  GCAAGATTATCC
# 44152783  GCTCTCACTGCAACTTCACCGAGATGT  ENSMUSG00000052305  GCAAGCACGTTT
# ...                               ...                 ...           ...
# 42720395  GCGAGTAACGCTGCGATAGTCTCGAAG  ENSMUSG00000113086  GCAGTCCCGGTT
# 32868423  CTTACGCAGCTGTGGTATGACATGGCT  ENSMUSG00000115507  CGGGTAAGCGCC
# 768035    AACACCGTTAACGTCCAAACTGGTTCC  ENSMUSG00000065604  CTTTGTAACCGC
# 21218890  CAGTCTTCGAACGTCCAAGACTATTCC  ENSMUSG00000065836  TCCTCGAGTGTT
# 34045745  GAACGCTATACGTTACGATAAGAGCGT  ENSMUSG00000112371  GTCCGCGAGACG
#
#           count  total_counts      zscore
# 0             1      35016187  105.483428
# 58948068      1      35016187  105.483428
# 44152781      2      35016187  105.483428
# 44152782      3      35016187  105.483428
# 44152783      1      35016187  105.483428
# ...         ...           ...         ...
# 42720395      1             1   -0.027150
# 32868423      1             1   -0.027150
# 768035        1             1   -0.027150
# 21218890      1             1   -0.027150
# 34045745      1             1   -0.027150
#
# [68445636 rows x 6 columns]

# %%
df_temp.drop_duplicates('geneID').zscore.tolist()[:10]
# Out:
# [105.48342824747625,
#  101.87386531884874,
#  72.26309159086644,
#  20.51821977787811,
#  9.256429482172075,
#  9.254868647426964,
#  6.874719202106183,
#  5.054026564295209,
#  4.9486822717781465,
#  3.786484117929335]

# %%
df_temp = df1.copy()

# %%
        df_temp['total_counts'] = df_temp.groupby('geneID')['count'].transform('sum')
        df_temp.sort_values('total_counts', ascending=False, inplace=True)
        data_std = np.std(df_temp.drop_duplicates('geneID').total_counts)
        data_mean = np.mean(df_temp.drop_duplicates('geneID').total_counts)
        df_temp['zscore'] = df_temp['total_counts'].apply(lambda x: (x-data_mean)/data_std)
        df_temp
# Out:
#                             Barcode           geneID        UMI  count  \
# 67513841   CAGATCTGACTATGCAGAACAGGC  ENSG00000158874  TAGCGAGCC      1
# 27142194   ACCACTGTAGCCATGCCCTCTATC  ENSG00000158874  CTGTGGCAT      1
# 27142200   ACCACTGTAGCCATGCCCTCTATC  ENSG00000158874  GACGGAACC      3
# 27142199   ACCACTGTAGCCATGCCCTCTATC  ENSG00000158874  GAATGGCGT      2
# 90301467   CGCATACATCCGTCTAACCACTGT  ENSG00000158874  AAGAGAGTC      1
# ...                             ...              ...        ...    ...
# 32684777   ACTATGCAAACAACCACAAGGAGC  ENSG00000212145  AAAGCATCG      1
# 106314214  GACTAGTATGGAACAAGAATCTGA  ENSG00000243064  GGGGACTCC      1
# 59884473   CAAGACTAACAGCAGAGTGTTCTA  ENSG00000233778  GGGCTCGTA      1
# 103546682  GACAGTGCAGAGTCAAAAGAGATC  ENSG00000214797  ACGACGACT      1
# 22296637   ACACGACCTGGTGGTACCTCTATC  ENSG00000255265  CAGCGTGTC      1
#
#            total_counts      zscore
# 67513841       14617744  125.033097
# 27142194       14617744  125.033097
# 27142200       14617744  125.033097
# 27142199       14617744  125.033097
# 90301467       14617744  125.033097
# ...                 ...         ...
# 32684777              1   -0.062515
# 106314214             1   -0.062515
# 59884473              1   -0.062515
# 103546682             1   -0.062515
# 22296637              1   -0.062515
#
# [142541473 rows x 6 columns]

# %%
df_temp.drop_duplicates('geneID').zscore.tolist()[:10]
# Out:
# [125.03309732932877,
#  60.50810303585075,
#  49.5846884304224,
#  43.559138127901306,
#  39.482744891061714,
#  36.48599420637836,
#  30.663742824021686,
#  27.948192645218228,
#  27.145959496835772,
#  27.0315161368695]

# %%
df2 = pd.read_table('/SGRNJ06/randd/PROJECT/RD20073101_ScRNA_VDJ/LZL_2022/20220804/H_0727PBMC1_Nlib/05.count/H_0727PBMC1_Nlib_count_detail.txt', header=0)

# %%
df_temp = df2.copy()

# %%
df_temp
# Out:
#                            Barcode           geneID        UMI  count
# 0         AAACATCGAAACATCGAAACATCG  ENSG00000000938  GACGGGCGT      4
# 1         AAACATCGAAACATCGAACAACCA  ENSG00000197971  AAAAACGTC      1
# 2         AAACATCGAAACATCGAACAACCA  ENSG00000197971  CACGGAGGC      1
# 3         AAACATCGAAACATCGAACAACCA  ENSG00000162704  AAAACGAGG      3
# 4         AAACATCGAAACATCGAACAACCA  ENSG00000162704  AAAGGCCGA      3
# ...                            ...              ...        ...    ...
# 20550198  TTCACGCATTCACGCATGGAACAA  ENSG00000080371  CAAACCCAT      3
# 20550199  TTCACGCATTCACGCATGGAACAA  ENSG00000163220  GCAATGATG      1
# 20550200  TTCACGCATTCACGCATGGCTTCA  ENSG00000115271  GAGAGCTGA      1
# 20550201  TTCACGCATTCACGCATGGCTTCA  ENSG00000166710  GCGCAGACC      1
# 20550202  TTCACGCATTCACGCATGGTGGTA  ENSG00000163191  TATAAGGAG      1
#
# [20550203 rows x 4 columns]

# %%
        df_temp['total_counts'] = df_temp.groupby('geneID')['count'].transform('sum')
        df_temp.sort_values('total_counts', ascending=False, inplace=True)
        data_std = np.std(df_temp.drop_duplicates('geneID').total_counts)
        data_mean = np.mean(df_temp.drop_duplicates('geneID').total_counts)
        df_temp['zscore'] = df_temp['total_counts'].apply(lambda x: (x-data_mean)/data_std)
        df_temp
# Out:
#                            Barcode           geneID        UMI  count  \
# 9703519   CAGCGTTAAACTCACCACACGACC  ENSG00000251562  CGAAACGTA      2
# 6592407   AGTACAAGTCTTCACACGGATTGC  ENSG00000251562  GGTGAACAT      1
# 19046894  TATCAGCAGAATCTGATGGTGGTA  ENSG00000251562  CTAAGCCTT      1
# 6592456   AGTACAAGTCTTCACACTGAGCCA  ENSG00000251562  CGGCAGTCC      1
# 6592457   AGTACAAGTCTTCACACTGAGCCA  ENSG00000251562  CGGCAGTCT      4
# ...                            ...              ...        ...    ...
# 2986251   ACACGACCAGTCACTAAATCCGTC  ENSG00000278147  GCAGTCAAC      1
# 2522554   ACAAGCTAAAGGACACAGATCGCA  ENSG00000221263  TCCGTGACA      1
# 16886122  GCGAGTAACGAACTTACACCTTAC  ENSG00000226823  TGGGAAATC      1
# 10981760  CCGAAGTATCTTCACAAGTGGTCA  ENSG00000252397  TGGTTCCTC      1
# 20210548  TGGTGGTAACTATGCAATGCCTAA  ENSG00000235189  TAGGATAGC      1
#
#           total_counts     zscore
# 9703519        1423264  72.017549
# 6592407        1423264  72.017549
# 19046894       1423264  72.017549
# 6592456        1423264  72.017549
# 6592457        1423264  72.017549
# ...                ...        ...
# 2986251              1  -0.089042
# 2522554              1  -0.089042
# 16886122             1  -0.089042
# 10981760             1  -0.089042
# 20210548             1  -0.089042
#
# [20550203 rows x 6 columns]

# %%
df_temp.drop_duplicates('geneID').zscore.tolist()[:10]
# Out:
# [72.01754877045545,
#  70.93620044410547,
#  65.48127842169028,
#  54.232601093191,
#  29.007506779192376,
#  25.681235959921917,
#  20.89703969146791,
#  15.111593096287194,
#  14.979869630746059,
#  14.057906697700842]

# %%
df3 = pd.read_table('/SGRNJ03/PROJ03/PROJ_20.SC/P21100502_SCOPEv2/temp/GC-NA014_auto/GC-NA014/05.count/GC-NA014_count_detail.txt', header=0)
df_temp = df3.copy()

# %%
        df_temp['total_counts'] = df_temp.groupby('geneID')['count'].transform('sum')
        df_temp.sort_values('total_counts', ascending=False, inplace=True)
        data_std = np.std(df_temp.drop_duplicates('geneID').total_counts)
        data_mean = np.mean(df_temp.drop_duplicates('geneID').total_counts)
        df_temp['zscore'] = df_temp['total_counts'].apply(lambda x: (x-data_mean)/data_std)
        df_temp
# Out:
#                            Barcode           geneID        UMI  count  \
# 67356326  GAATCTGACTGGCATAAACTCACC  ENSG00000182333  GGCACGTGT      2
# 7319914   AAGAGATCCAAGGAGCGAGCTGAA  ENSG00000182333  CCTATCATG      3
# 7319928   AAGAGATCCAAGGAGCGAGCTGAA  ENSG00000182333  CCTTTATAA      5
# 7319927   AAGAGATCCAAGGAGCGAGCTGAA  ENSG00000182333  CCTTGCTGG      5
# 7319926   AAGAGATCCAAGGAGCGAGCTGAA  ENSG00000182333  CCTTGCATT      1
# ...                            ...              ...        ...    ...
# 81311581  GTACGCAAGTCGTAGAAACAACCA  ENSG00000223640  AAACTGTCG      1
# 45468901  CATACCAACCTCCTGAAGCCATGC  ENSG00000279685  AGCCGGTCA      1
# 52336484  CCTAATCCCCTCTATCTAGGATGA  ENSG00000231355  TTGATGCGC      1
# 54626326  CCTCTATCTCTTCACAAGCCATGC  ENSG00000279340  GGCCTAAAG      1
# 45381874  CATACCAACAGCGTTAACCTCCAA  ENSG00000222931  TCTGCCGCG      1
#
#           total_counts     zscore
# 67356326      14892466  99.863067
# 7319914       14892466  99.863067
# 7319928       14892466  99.863067
# 7319927       14892466  99.863067
# 7319926       14892466  99.863067
# ...                ...        ...
# 81311581             1  -0.036655
# 45468901             1  -0.036655
# 52336484             1  -0.036655
# 54626326             1  -0.036655
# 45381874             1  -0.036655
#
# [93031689 rows x 6 columns]

# %%
df_temp
# Out:
#                            Barcode           geneID        UMI  count  \
# 67356326  GAATCTGACTGGCATAAACTCACC  ENSG00000182333  GGCACGTGT      2
# 7319914   AAGAGATCCAAGGAGCGAGCTGAA  ENSG00000182333  CCTATCATG      3
# 7319928   AAGAGATCCAAGGAGCGAGCTGAA  ENSG00000182333  CCTTTATAA      5
# 7319927   AAGAGATCCAAGGAGCGAGCTGAA  ENSG00000182333  CCTTGCTGG      5
# 7319926   AAGAGATCCAAGGAGCGAGCTGAA  ENSG00000182333  CCTTGCATT      1
# ...                            ...              ...        ...    ...
# 81311581  GTACGCAAGTCGTAGAAACAACCA  ENSG00000223640  AAACTGTCG      1
# 45468901  CATACCAACCTCCTGAAGCCATGC  ENSG00000279685  AGCCGGTCA      1
# 52336484  CCTAATCCCCTCTATCTAGGATGA  ENSG00000231355  TTGATGCGC      1
# 54626326  CCTCTATCTCTTCACAAGCCATGC  ENSG00000279340  GGCCTAAAG      1
# 45381874  CATACCAACAGCGTTAACCTCCAA  ENSG00000222931  TCTGCCGCG      1
#
#           total_counts     zscore
# 67356326      14892466  99.863067
# 7319914       14892466  99.863067
# 7319928       14892466  99.863067
# 7319927       14892466  99.863067
# 7319926       14892466  99.863067
# ...                ...        ...
# 81311581             1  -0.036655
# 45468901             1  -0.036655
# 52336484             1  -0.036655
# 54626326             1  -0.036655
# 45381874             1  -0.036655
#
# [93031689 rows x 6 columns]

# %%
df_temp.drop_duplicates('geneID').zscore.tolist()[:10]
# Out:
# [99.86306738999997,
#  83.60269505881809,
#  68.09954326900085,
#  55.774300163900925,
#  45.71945085735753,
#  43.74701618431557,
#  33.56889935356001,
#  31.09883309496326,
#  29.97619035173436,
#  28.410727676212396]

# %%
df4 = pd.read_table('/SGRNJ03/PROJ03/PROJ_20.SC/P21100502_SCOPEv2/temp/NA016CA_auto/NA016CA/05.count/NA016CA_count_detail.txt', header=0)
df_temp = df4.copy()

# %%
        df_temp['total_counts'] = df_temp.groupby('geneID')['count'].transform('sum')
        df_temp.sort_values('total_counts', ascending=False, inplace=True)
        data_std = np.std(df_temp.drop_duplicates('geneID').total_counts)
        data_mean = np.mean(df_temp.drop_duplicates('geneID').total_counts)
        df_temp['zscore'] = df_temp['total_counts'].apply(lambda x: (x-data_mean)/data_std)
        df_temp
# Out:
#                            Barcode           geneID        UMI  count  \
# 36503770  CCTCCTGACAATGGAAAACAACCA  ENSG00000210082  GAACGATTG      3
# 38973941  CGACTGGAAACGTGATACACGACC  ENSG00000210082  CATGTAGGT      1
# 22855536  ATAGCGACGAACAGGCAACTCACC  ENSG00000210082  GGAAGGAAC      1
# 22855535  ATAGCGACGAACAGGCAACTCACC  ENSG00000210082  GATCCCTGA      3
# 22855534  ATAGCGACGAACAGGCAACTCACC  ENSG00000210082  GATCATGTG      2
# ...                            ...              ...        ...    ...
# 46796331  GACTAGTAACAAGCTATGGTGGTA  ENSG00000274469  TACCCTGTC      1
# 52684520  GCTCGGTACAGATCTGGAGTTAGC  ENSG00000265136  CCGGGTAAA      1
# 47972421  GAGTTAGCAACAACCAAGATGTAC  ENSG00000255313  ACGCCTGAT      1
# 54043223  GGTGCGAAATCATTCCGTACGCAA  ENSG00000234325  GTATATGCA      1
# 20690022  AGTACAAGGAACAGGCACACGACC  ENSG00000277437  CCAAGGCGT      1
#
#           total_counts      zscore
# 36503770      16102117  164.011099
# 38973941      16102117  164.011099
# 22855536      16102117  164.011099
# 22855535      16102117  164.011099
# 22855534      16102117  164.011099
# ...                ...         ...
# 46796331             1   -0.027399
# 52684520             1   -0.027399
# 47972421             1   -0.027399
# 54043223             1   -0.027399
# 20690022             1   -0.027399
#
# [62758484 rows x 6 columns]

# %%
df_temp.drop_duplicates('geneID').zscore.tolist()[:10]
# Out:
# [164.01109886964917,
#  59.981764548363586,
#  56.324910059461786,
#  55.67890743283802,
#  37.85270068730572,
#  37.513745924910175,
#  36.91113138235237,
#  27.205250595176512,
#  26.003627845294368,
#  24.953022930160703]
