# %%
suppressWarnings(suppressMessages({
    library(Signac)
    library(Seurat)
    library(EnsDb.Mmusculus.v79)
    library(tidyverse)
    library(SingleR)
    library(EnsDb.Hsapiens.v75)
}))

# %%
rds = Read10X_h5("/SGRNJ06/randd/PROJECT/scATAC/self_pipe/20231212_M_959595_sc/A1120_3_MLNheart_guozhu_YSPB_WX_D002SDS_T7_EDTA5030/02.atac/Result/QC/A1120_3_MLNheart_guozhu_YSPB_WX_D002SDS_T7_EDTA5030//A1120_3_MLNheart_guozhu_YSPB_WX_D002SDS_T7_EDTA5030_filtered_peak_count.h5")
rds1 = Read10X_h5("/SGRNJ06/randd/PROJECT/scATAC/20231212_M_959595_sc/A1120_3_MLNheart_guozhu_YSPB_WX_D002SDS_T7_EDTA5030/03.atac/A1120_3_MLNheart_guozhu_YSPB_WX_D002SDS_T7_EDTA5030/outs/filtered_peak_bc_matrix.h5")

# %%
dim(rds)

# %%
dim(rds1)

# %%
df <- as.data.frame(colSums(rds))
df$barcode <- rownames(df)
df1 <- as.data.frame(colSums(rds1))
df1$barcode <- rownames(df1)

# %%
median(df$`colSums(rds)`)

# %%
median(df1$`colSums(rds1)`)

# %%
sum(df$`colSums(rds)`)

# %%
sum(df1$`colSums(rds1)`)

# %%
sort(df$`colSums(rds)`)

# %%
sort(df1$`colSums(rds1)`)

# %%
df1

# %%
df2 = df1[df1[,"colSums(rds1)"]>999,]

# %%
median(df2$`colSums(rds1)`)

# %%
rds = Read10X_h5("/SGRNJ06/randd/PROJECT/scATAC/20231006_ME_sc/A0920_3_ME_YSPB_WX_D_T7_EDTA5030/03.atac/A0920_3_ME_YSPB_WX_D_T7_EDTA5030/outs/raw_peak_bc_matrix.h5")
rds1 = Read10X_h5("/SGRNJ06/randd/USER/cjj/celedev/atac/MAESTRO/test/20231220/A0920_3_ME_YSPB_WX_D_T7_EDTA5030/02.atac/Result/Analysis/A0920_3_ME_YSPB_WX_D_T7_EDTA5030/A0920_3_ME_YSPB_WX_D_T7_EDTA5030_peak_count.h5")

# %%
dim(rds)

# %%
dim(rds1)

# %%
df <- as.data.frame(colSums(rds))
df$barcode <- rownames(df)
df1 <- as.data.frame(colSums(rds1))
df1$barcode <- rownames(df1)

# %%
median(df$`colSums(rds)`)

# %%
median(df1$`colSums(rds1)`)

# %%
rds2 = Read10X_h5("/SGRNJ06/randd/PROJECT/scATAC/self_pipe/mouse/A0920_3_ME_YSPB_WX_D_T7_EDTA5030/outs/A0920_3_ME_YSPB_WX_D_T7_EDTA5030_filtered_peak_count.h5")

# %%
dim(rds2)

# %%
rds = Read10X_h5("/SGRNJ06/randd/PROJECT/scATAC/self_pipe/mouse/A0920_3_ME_YSPB_WX_D_T7_EDTA5030/outs/A0920_3_ME_YSPB_WX_D_T7_EDTA5030_filtered_peak_count.h5")
rds1 = Read10X_h5("/SGRNJ06/randd/PROJECT/scATAC/20231006_ME_sc/A0920_3_ME_YSPB_WX_D_T7_EDTA5030/03.atac/A0920_3_ME_YSPB_WX_D_T7_EDTA5030/outs/filtered_peak_bc_matrix.h5")

# %%
rds
# Out:
#   [[ suppressing 31 column names 'AACAATAACGTCTCCAAGGA', 'AACAATAACGTCTCGATCTT', 'AACAATACAGCTCACGCGTA' ... ]]
#
#   [[ suppressing 31 column names 'AACAATAACGTCTCCAAGGA', 'AACAATAACGTCTCGATCTT', 'AACAATACAGCTCACGCGTA' ... ]]
#
#   [[ suppressing 31 column names 'AACAATAACGTCTCCAAGGA', 'AACAATAACGTCTCGATCTT', 'AACAATACAGCTCACGCGTA' ... ]]
# 168012 x 7880 sparse Matrix of class "dgCMatrix"
#
# chr10_100015448_100016706 . . . 1 . . . . . . . . . . . . 1 . . . . 1 . . . . . . . . . ......
# chr10_100019365_100019705 . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . ......
# chr10_100022115_100022607 . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . ......
# chr10_100024797_100024939 . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . ......
# chr10_100031148_100031501 . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . ......
# chr10_100032699_100032836 . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . ......
# ...

# %%
rds1
# Out:
#   [[ suppressing 31 column names 'AAATGAGAGAACAGGA-1', 'AAATGAGAGAAGACTT-1', 'AAATGAGAGAATCAAC-1' ... ]]
#
#   [[ suppressing 31 column names 'AAATGAGAGAACAGGA-1', 'AAATGAGAGAAGACTT-1', 'AAATGAGAGAATCAAC-1' ... ]]
#
#   [[ suppressing 31 column names 'AAATGAGAGAACAGGA-1', 'AAATGAGAGAAGACTT-1', 'AAATGAGAGAATCAAC-1' ... ]]
# 181730 x 7371 sparse Matrix of class "dgCMatrix"
#
# chr1:3094558-3095456   . . . . . . . . . . . . . . . . . . . . . 2 . . . . . . . . . ......
# chr1:3119609-3120531   . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . ......
# chr1:3121272-3121966   . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . ......
# chr1:3297177-3298080   . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . ......
# chr1:3395281-3396216   . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . ......
# chr1:3399675-3400571   . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . ......
# ...
