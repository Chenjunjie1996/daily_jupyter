# %%
library(Seurat)
# Out:
# Warning message:
# “package ‘Seurat’ was built under R version 4.0.5”
# Attaching SeuratObject

# %%
rds =readRDS('/SGRNJ06/randd/PROJECT/RD20073101_ScRNA_VDJ/20220425_kmc3/sc-2/06.analysis/220417015X1.rds')

# %%
UMAPPlot(rds)
# Out:
# plot without title

# %%
Tcells NKcells
