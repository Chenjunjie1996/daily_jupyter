# %%
import pandas as pd

# %%
meta = pd.read_csv('/SGRNJ06/randd/USER/cjj/celedev/vdj10x/20220602cellnum/meta.tsv',sep='\t')

# %%
meta = meta.rename_axis('barcode').reset_index()

# %%
meta.groupby('new_ident').count()
# Out:
#            barcode
# new_ident
# Bcells         319
# Tcells        3341

# %%
meta = meta[meta['orig.ident']=='H_0421PBMC_2_Nlib']

# %%
meta
# Out:
#                                           barcode         orig.ident  \
# 9012   H_0421PBMC_2_Nlib_AAACATCGAACCGAGAAACAACCA  H_0421PBMC_2_Nlib
# 9013   H_0421PBMC_2_Nlib_AAACATCGAACGCTTACTCAATGA  H_0421PBMC_2_Nlib
# 9014   H_0421PBMC_2_Nlib_AAACATCGAACGTGATGAGTTAGC  H_0421PBMC_2_Nlib
# 9015   H_0421PBMC_2_Nlib_AAACATCGAACTCACCTCCGTCTA  H_0421PBMC_2_Nlib
# 9016   H_0421PBMC_2_Nlib_AAACATCGAAGACGGACTGGCATA  H_0421PBMC_2_Nlib
# ...                                           ...                ...
# 17581  H_0421PBMC_2_Nlib_TTCACGCATATCAGCAGATGAATC  H_0421PBMC_2_Nlib
# 17582  H_0421PBMC_2_Nlib_TTCACGCATGGAACAAGATAGACA  H_0421PBMC_2_Nlib
# 17583  H_0421PBMC_2_Nlib_TTCACGCATGGAACAAGGTGCGAA  H_0421PBMC_2_Nlib
# 17584  H_0421PBMC_2_Nlib_TTCACGCATGGTGGTAACCACTGT  H_0421PBMC_2_Nlib
# 17585  H_0421PBMC_2_Nlib_TTCACGCATGGTGGTATTCACGCA  H_0421PBMC_2_Nlib
#
#        nCount_RNA  nFeature_RNA             sample  percent.mt  percent.mito  \
# ...

# %%
meta.barcode = meta.barcode.apply(lambda x:x.split('_')[-1])
# Out:
# /Personal/chenjunjie/.local/lib/python3.7/site-packages/pandas/core/generic.py:5491: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
meta
# Out:
#                         barcode         orig.ident  nCount_RNA  nFeature_RNA  \
# 9012   AAACATCGAACCGAGAAACAACCA  H_0421PBMC_2_Nlib        1517           832
# 9013   AAACATCGAACGCTTACTCAATGA  H_0421PBMC_2_Nlib         658           387
# 9014   AAACATCGAACGTGATGAGTTAGC  H_0421PBMC_2_Nlib         780           481
# 9015   AAACATCGAACTCACCTCCGTCTA  H_0421PBMC_2_Nlib        2844          1356
# 9016   AAACATCGAAGACGGACTGGCATA  H_0421PBMC_2_Nlib        2817          1214
# ...                         ...                ...         ...           ...
# 17581  TTCACGCATATCAGCAGATGAATC  H_0421PBMC_2_Nlib        1376           755
# 17582  TTCACGCATGGAACAAGATAGACA  H_0421PBMC_2_Nlib        2090          1001
# 17583  TTCACGCATGGAACAAGGTGCGAA  H_0421PBMC_2_Nlib        1574           725
# 17584  TTCACGCATGGTGGTAACCACTGT  H_0421PBMC_2_Nlib        1437           807
# 17585  TTCACGCATGGTGGTATTCACGCA  H_0421PBMC_2_Nlib        1057           661
#
# ...

# %%
raw = pd.read_csv('/SGRNJ06/randd/PROJECT/RD20073101_ScRNA_VDJ/20220516/H_0421PBMC_2_NM_3TNlib/06.summarize/productive/productive_match_contig_annotations.csv')
jiace = pd.read_csv('/SGRNJ06/randd/PROJECT/RD20073101_VDJ/20220601/H_0421PBMC_2_NM_3TNlib/06.summarize/productive/productive_match_contig_annotations.csv')

# %%
raw_bc = set(raw.barcode)
jiace_bc = set(jiace.barcode)

# %%
len(raw_bc)
# Out:
# 2595

# %%
len(jiace_bc)
# Out:
# 1572

# %%
diff = raw_bc - jiace_bc
diff1 = jiace_bc - raw_bc

# %%
intersec = raw_bc.intersection(jiace_bc)

# %%
len(diff1)
# Out:
# 376

# %%
len(intersec)
# Out:
# 1196

# %%
meta = meta[['barcode','new_ident']]

# %%
meta
# Out:
#                         barcode new_ident
# 9012   AAACATCGAACCGAGAAACAACCA       NaN
# 9013   AAACATCGAACGCTTACTCAATGA       NaN
# 9014   AAACATCGAACGTGATGAGTTAGC       NaN
# 9015   AAACATCGAACTCACCTCCGTCTA       NaN
# 9016   AAACATCGAAGACGGACTGGCATA       NaN
# ...                         ...       ...
# 17581  TTCACGCATATCAGCAGATGAATC    Tcells
# 17582  TTCACGCATGGAACAAGATAGACA       NaN
# 17583  TTCACGCATGGAACAAGGTGCGAA    Bcells
# 17584  TTCACGCATGGTGGTAACCACTGT       NaN
# 17585  TTCACGCATGGTGGTATTCACGCA       NaN
#
# [8574 rows x 2 columns]

# %%
meta[meta['barcode'].isin(intersec)].groupby('new_ident').count()
# Out:
#            barcode
# new_ident
# Bcells          10
# Tcells        1098

# %%
meta[meta['barcode'].isin(diff1)].groupby('new_ident').count()
# Out:
#            barcode
# new_ident
# Bcells          11
# Tcells         201

# %%
from matplotlib_venn import venn2
from matplotlib import pyplot as plt

# %%
    data_cr_set = set(raw_bc)
    data_tr_set = set(jiace_bc)
    subset_ = [raw_bc, jiace_bc]
    venn2(subset_, set_labels=('raw', 'jiace'), set_colors=('r', 'g'))
    plt.savefig('/SGRNJ06/randd/USER/cjj/celedev/vdj10x/20220602cellnum/rawVSjiace.png')
