# %%
import pandas as pd
import pysam

# %%
handle_file = open('/SGRNJ06/randd/USER/cjj/celedev/vdj10x/20220511_BCR_analy/top20bp/R220429124.txt', 'w')
with pysam.FastxFile('/SGRNJ06/DATA04/22_05/2022_05_09/gwo0vdqnkf/S_Mbm_A_3NL/R220429124_R1.fastq.gz') as f:
    for read in f:
        handle_file.write(str(read.sequence[:20]) + '\n')
handle_file.close()

# %%
from collections import Counter

# %%
a = pd.read_csv('/SGRNJ06/randd/USER/cjj/celedev/vdj10x/20220511_BCR_analy/top20bp/R220429135.txt',header=None)

# %%
a = a.rename(columns={0:'bc'})

# %%
bc = a.bc.to_list()

# %%
c = Counter(bc)

# %%
cc=sorted(c.items(),key=lambda x:x[1],reverse=True)

# %%
cc[0][0]
# Out:
# 'AAGCAGTGGTATCAACGCAG'

# %%
with open('/SGRNJ06/randd/USER/cjj/celedev/vdj10x/20220511_BCR_analy/top20bp/top10/R220429135.txt','w') as f:
    for i in range(10):
        f.write(cc[i][0] +' '+str(cc[i][1])+ '\n')

# %%
# Out:
# [('AAGCAGTGGTATCAACGCAG', 9806484),
#  ('CACATTCACTCTGCGTTGAT', 96810),
#  ('AAGCAGTGTATCAACGCAGA', 16031),
#  ('ANGCAGTGGTATCAACGCAG', 15307),
#  ('AGCAGTGGTATCAACGCAGA', 14316),
#  ('AAGCAGTGGTATCACGCAGA', 13223),
#  ('AAGCAGTGGTATCAACGCGG', 10890),
#  ('AAGCAGTGGTACCAACGCAG', 10865),
#  ('AAGCAGTGGTTCAACGCAGA', 10318),
#  ('CACATTCACGACGCCCCTCC', 10191),
#  ('AAGCAGTGGTATCAGCGCAG', 10142),
#  ('AAGCAGCGGTATCAACGCAG', 9703),
#  ('AAGCAGTGGTATCGACGCAG', 9462),
#  ('AAGCAGTGGTACAACGCAGA', 8876),
#  ('AAGCAGTGGCATCAACGCAG', 8704),
#  ('AAGCAGTGGTATCAATGCAG', 8672),
#  ('AAGCGGTGGTATCAACGCAG', 8578),
#  ('GATTCACTCTGCGTTGATAC', 8562),
#  ('AGGCAGTGGTATCAACGCAG', 8382),
#  ('AAGCATGGTATCAACGCAGA', 8381),
#  ('AAGCAGGGTATCAACGCAGA', 7982),
#  ('GACCACTATTCACTCTGCGT', 7957),
#  ('AAGCAGTGGTGTCAACGCAG', 7839),
#  ('AAGCAGTGGTATCAACACAG', 7678),
#  ('AAGCAGTGGTATCAACGCAA', 7314),
#  ('AAAGCAGTGGTATCAACGCA', 7269),
#  ('CAGCAGTGGTATCAACGCAG', 7244),
#  ('CACATTCACGACGCCCCCCC', 7242),
# ...
