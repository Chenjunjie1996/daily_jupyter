# %%
library('Seurat')

# %%
# 细分
rds = readRDS('/SGRNJ06/randd/USER/cjj/celedev/XZMU/20221110/Tcells.rds')
rds = NormalizeData(rds)
rds = ScaleData(rds)
rds <- FindVariableFeatures(object = rds)
genes.use<- head(HVFInfo(object = rds),2000)
rds <- RunPCA(object=rds,features = VariableFeatures(object = rds))
rds <- FindNeighbors(rds, reduction = "pca", dims = 1:20)
rds <- FindClusters(rds,resolution = 0.8, algorithm = 1)
rds <- RunTSNE(object=rds,dims.use=1:20,do.fast=TRUE,check_duplicates = FALSE)
rds <- RunUMAP(rds, reduction = "pca", dims = 1:20)
saveRDS(rds, '/SGRNJ06/randd/USER/cjj/celedev/XZMU/20221110/Tcells_scaled.rds')

# %%
# subset
rds = readRDS('/SGRNJ06/randd/USER/cjj/celedev/XZMU/20230213/rename.rds')
Idents(rds) <- 'car'
rds <- subset(rds,idents = c('CAR+'))

# %%
saveRDS(rds, "/SGRNJ06/randd/USER/cjj/celedev/XZMU/20221110/Tcells_car_pos.rds")

# %%
# marker gene
library('Seurat')
rds = readRDS('/SGRNJ06/randd/USER/cjj/celedev/XZMU/20221110/Tcells_scaled.rds')
Idents(rds) <- "sample"
diff.wilcox = FindAllMarkers(rds)

# %%
write.csv(diff.wilcox,"/SGRNJ06/randd/USER/cjj/celedev/XZMU/20221110/allmarkers.csv")

# %%
library('Seurat')
library('ggplot2')
library("ggsci")
library('tidyverse')
library('monocle')
options(warn=-1)

# %%
#rds = readRDS('/SGRNJ06/randd/USER/cjj/celedev/XZMU/20220923analysis/GC_1.2_T.rds')
#rds = readRDS('/SGRNJ06/randd/USER/cjj/celedev/XZMU/20221110/Tcells.rds')
#rds = readRDS('/SGRNJ06/randd/USER/cjj/celedev/XZMU/20221110/Tcells_scaled.rds')
#rds = readRDS('/SGRNJ06/randd/USER/cjj/celedev/XZMU/20221110/Tcells_car_pos.rds')
#rds = readRDS('/SGRNJ06/randd/USER/cjj/celedev/yihe/S21.rds')
#rds  =readRDS("/SGRNJ06/randd/USER/cjj/celedev/XZMU/20230103/monocle/dyc_T.rds")
rds  =readRDS("/SGRNJ06/randd/USER/cjj/celedev/XZMU/20230213/rename.rds")

# %%
table(rds@meta.data$sample)

# %%
data <- as.sparse(rds@assays$RNA@counts)
pd <- new('AnnotatedDataFrame', data = rds@meta.data)
fData <- data.frame(gene_short_name = row.names(data), row.names = row.names(data))
fd <- new('AnnotatedDataFrame', data = fData)
#Construct monocle cds
monocle_cds <- newCellDataSet(data,
                              phenoData = pd,
                              featureData = fd,
                              expressionFamily = negbinomial.size())
HSMM<-monocle_cds

# %%
HSMM <- estimateSizeFactors(HSMM)
HSMM <- estimateDispersions(HSMM)
# Out:
# Removing 117 outliers

# %%
diff.wilcox = read.csv('/SGRNJ06/randd/USER/cjj/celedev/XZMU/20221110/allmarkers.csv')

# %%
##使用clusters差异表达基因
#Idents(rds) <- "sample"
#diff.wilcox = FindAllMarkers(rds)
all.markers = diff.wilcox %>% subset(p_val<0.05)
#diff.genes <- subset(all.markers,p_val_adj<0.01)$gene
diff.genes <- subset(all.markers,p_val_adj<0.05)$gene
HSMM <- setOrderingFilter(HSMM, diff.genes)
p1 <- plot_ordering_genes(HSMM)

# %%
p1
# Out:
# plot without title

# %%
##使用seurat选择的高变基因
var.genes <- VariableFeatures(rds)
HSMM <- setOrderingFilter(HSMM, var.genes)
p2 <- plot_ordering_genes(HSMM)

# %%
##使用monocle选择的高变基因
disp_table <- dispersionTable(HSMM)
disp.genes <- subset(disp_table, mean_expression >= 0.1 & dispersion_empirical >= 1 * dispersion_fit)$gene_id
HSMM <- setOrderingFilter(HSMM, disp.genes)
p3 <- plot_ordering_genes(HSMM)

# %%
p3
#p1 | p2 | p3
# Out:
# plot without title

# %%
HSMM <- reduceDimension(HSMM, max_components = 2, method = 'DDRTree')
HSMM <- orderCells(HSMM)

# %%
HSMM@phenoData@data
# Out:
#                               orig.ident nCount_RNA nFeature_RNA sample
# WYP0_AAACATCGAACGTGATCCGACAAC WYP0        7833      2217         WYP0
# WYP0_AAACATCGAAGGACACTTCACGCA WYP0       20314      4008         WYP0
# WYP0_AAACATCGACACGACCAGTGGTCA WYP0        3749      1460         WYP0
# WYP0_AAACATCGACCACTGTAACTCACC WYP0        4499      1465         WYP0
# WYP0_AAACATCGACCACTGTAAGAGATC WYP0        5290      1783         WYP0
# WYP0_AAACATCGAGGCTAACCATACCAA WYP0       13977      3205         WYP0
# WYP0_AAACATCGAGTGGTCAAATCCGTC WYP0        6869      2041         WYP0
# WYP0_AAACATCGATAGCGACATCATTCC WYP0        6394      2226         WYP0
# WYP0_AAACATCGATCATTCCGACTAGTA WYP0        4810      1618         WYP0
# WYP0_AAACATCGATCCTGTACCAGTTCA WYP0       18102      3898         WYP0
# WYP0_AAACATCGCACCTTACCACCTTAC WYP0       13268      3129         WYP0
# WYP0_AAACATCGCACCTTACCCGAAGTA WYP0        6773      2122         WYP0
# WYP0_AAACATCGCACTTCGAACAGATTC WYP0        9528      2813         WYP0
# WYP0_AAACATCGCAGATCTGTCTTCACA WYP0       23686      4283         WYP0
# WYP0_AAACATCGCCAGTTCACATCAAGT WYP0        7101      2103         WYP0
# WYP0_AAACATCGCCGACAACCCATCCTC WYP0       10784      2733         WYP0
# WYP0_AAACATCGCCGACAACCGACTGGA WYP0       10291      2832         WYP0
# WYP0_AAACATCGCCTAATCCAATGTTGC WYP0       17593      3832         WYP0
# WYP0_AAACATCGCGCTGATCCAACCACA WYP0       14607      3357         WYP0
# WYP0_AAACATCGCTAAGGTCAGTACAAG WYP0        7055      2864         WYP0
# WYP0_AAACATCGGACAGTGCAACGTGAT WYP0        8251      2447         WYP0
# WYP0_AAACATCGGAGCTGAACCTAATCC WYP0        9207      2442         WYP0
# WYP0_AAACATCGGTACGCAAAGCACCTC WYP0        7362      2348         WYP0
# WYP0_AAACATCGGTGTTCTAAGAGTCAA WYP0        3455      1300         WYP0
# WYP0_AAACATCGGTGTTCTACTGAGCCA WYP0       17405      3972         WYP0
# WYP0_AAACATCGTATCAGCAATTGGCTC WYP0        3857      1438         WYP0
# WYP0_AACAACCAAAACATCGGGTGCGAA WYP0        6375      2061         WYP0
# WYP0_AACAACCAAACAACCAGAATCTGA WYP0        6533      2197         WYP0
# WYP0_AACAACCAAACGCTTAAGTCACTA WYP0        6025      1812         WYP0
# WYP0_AACAACCAAAGACGGAAACTCACC WYP0       11137      2897         WYP0
# ⋮                             ⋮          ⋮          ⋮            ⋮
# WYP2_TGGAACAACCTCCTGAACCACTGT WYP2       14167      3429         WYP2
# WYP2_TGGAACAAGCCAAGACCCGACAAC WYP2        3550      1455         WYP2
# WYP2_TGGAACAAGCTAACGAACGTATCA WYP2        3366      1377         WYP2
# WYP2_TGGAACAATCTTCACAATGCCTAA WYP2        5587      2138         WYP2
# WYP2_TGGCTTCAAATGTTGCGTGTTCTA WYP2        3742      1536         WYP2
# WYP2_TGGCTTCAACCACTGTAGATCGCA WYP2        3625      1438         WYP2
# WYP2_TGGCTTCAATTGGCTCCGCATACA WYP2        3302      1334         WYP2
# WYP2_TGGCTTCACATCAAGTGCCAAGAC WYP2        4887      1753         WYP2
# WYP2_TGGCTTCACCGAAGTAAAGAGATC WYP2        7041      2203         WYP2
# WYP2_TGGCTTCACTAAGGTCAACAACCA WYP2        3061      1270         WYP2
# WYP2_TGGCTTCAGAGCTGAACCTCCTGA WYP2        3242      1239         WYP2
# WYP2_TGGCTTCAGATGAATCATTGGCTC WYP2        2917      1193         WYP2
# WYP2_TGGTGGTAAAACATCGAACGTGAT WYP2        3590      1383         WYP2
# WYP2_TGGTGGTAAATCCGTCGTACGCAA WYP2        5984      2023         WYP2
# WYP2_TGGTGGTAACAGATTCCACTTCGA WYP2        4396      1555         WYP2
# WYP2_TGGTGGTAACATTGGCAGCAGGAA WYP2        3097      1305         WYP2
# WYP2_TGGTGGTAAGAGTCAAAGCCATGC WYP2        3441      1417         WYP2
# WYP2_TGGTGGTAAGTGGTCACCAGTTCA WYP2        4238      1616         WYP2
# WYP2_TGGTGGTAATCATTCCAATGTTGC WYP2        6860      2233         WYP2
# WYP2_TGGTGGTAATCCTGTACTGGCATA WYP2        3100      1317         WYP2
# WYP2_TGGTGGTACAAGGAGCCCTCCTGA WYP2        3988      1492         WYP2
# WYP2_TGGTGGTACCGACAACCTGAGCCA WYP2       11109      3127         WYP2
# WYP2_TGGTGGTACTCAATGACGCTGATC WYP2       11709      3064         WYP2
# WYP2_TGGTGGTACTCAATGACTGGCATA WYP2        2636      1085         WYP2
# WYP2_TGGTGGTAGAGCTGAAGAATCTGA WYP2        3276      1333         WYP2
# WYP2_TGGTGGTAGCGAGTAAACCACTGT WYP2        4142      1816         WYP2
# WYP2_TTCACGCACTCAATGAAGTCACTA WYP2        4370      1735         WYP2
# WYP2_TTCACGCAGAGCTGAAACGCTCGA WYP2        4592      1798         WYP2
# WYP2_TTCACGCATGGCTTCAACAGATTC WYP2        7002      2162         WYP2
# WYP2_TTCACGCATGGTGGTACACTTCGA WYP2        3236      1274         WYP2
#                               sample_colors group group_colors reportname
# WYP0_AAACATCGAACGTGATCCGACAAC #FF1F1D       WYP0  #FF1F1D      WYP0
# WYP0_AAACATCGAAGGACACTTCACGCA #FF1F1D       WYP0  #FF1F1D      WYP0
# WYP0_AAACATCGACACGACCAGTGGTCA #FF1F1D       WYP0  #FF1F1D      WYP0
# WYP0_AAACATCGACCACTGTAACTCACC #FF1F1D       WYP0  #FF1F1D      WYP0
# WYP0_AAACATCGACCACTGTAAGAGATC #FF1F1D       WYP0  #FF1F1D      WYP0
# WYP0_AAACATCGAGGCTAACCATACCAA #FF1F1D       WYP0  #FF1F1D      WYP0
# WYP0_AAACATCGAGTGGTCAAATCCGTC #FF1F1D       WYP0  #FF1F1D      WYP0
# WYP0_AAACATCGATAGCGACATCATTCC #FF1F1D       WYP0  #FF1F1D      WYP0
# WYP0_AAACATCGATCATTCCGACTAGTA #FF1F1D       WYP0  #FF1F1D      WYP0
# WYP0_AAACATCGATCCTGTACCAGTTCA #FF1F1D       WYP0  #FF1F1D      WYP0
# WYP0_AAACATCGCACCTTACCACCTTAC #FF1F1D       WYP0  #FF1F1D      WYP0
# WYP0_AAACATCGCACCTTACCCGAAGTA #FF1F1D       WYP0  #FF1F1D      WYP0
# WYP0_AAACATCGCACTTCGAACAGATTC #FF1F1D       WYP0  #FF1F1D      WYP0
# WYP0_AAACATCGCAGATCTGTCTTCACA #FF1F1D       WYP0  #FF1F1D      WYP0
# WYP0_AAACATCGCCAGTTCACATCAAGT #FF1F1D       WYP0  #FF1F1D      WYP0
# WYP0_AAACATCGCCGACAACCCATCCTC #FF1F1D       WYP0  #FF1F1D      WYP0
# WYP0_AAACATCGCCGACAACCGACTGGA #FF1F1D       WYP0  #FF1F1D      WYP0
# WYP0_AAACATCGCCTAATCCAATGTTGC #FF1F1D       WYP0  #FF1F1D      WYP0
# WYP0_AAACATCGCGCTGATCCAACCACA #FF1F1D       WYP0  #FF1F1D      WYP0
# WYP0_AAACATCGCTAAGGTCAGTACAAG #FF1F1D       WYP0  #FF1F1D      WYP0
# WYP0_AAACATCGGACAGTGCAACGTGAT #FF1F1D       WYP0  #FF1F1D      WYP0
# WYP0_AAACATCGGAGCTGAACCTAATCC #FF1F1D       WYP0  #FF1F1D      WYP0
# WYP0_AAACATCGGTACGCAAAGCACCTC #FF1F1D       WYP0  #FF1F1D      WYP0
# WYP0_AAACATCGGTGTTCTAAGAGTCAA #FF1F1D       WYP0  #FF1F1D      WYP0
# WYP0_AAACATCGGTGTTCTACTGAGCCA #FF1F1D       WYP0  #FF1F1D      WYP0
# WYP0_AAACATCGTATCAGCAATTGGCTC #FF1F1D       WYP0  #FF1F1D      WYP0
# WYP0_AACAACCAAAACATCGGGTGCGAA #FF1F1D       WYP0  #FF1F1D      WYP0
# WYP0_AACAACCAAACAACCAGAATCTGA #FF1F1D       WYP0  #FF1F1D      WYP0
# WYP0_AACAACCAAACGCTTAAGTCACTA #FF1F1D       WYP0  #FF1F1D      WYP0
# WYP0_AACAACCAAAGACGGAAACTCACC #FF1F1D       WYP0  #FF1F1D      WYP0
# ⋮                             ⋮             ⋮     ⋮            ⋮
# WYP2_TGGAACAACCTCCTGAACCACTGT #B45B5D       WYP2  #B45B5D      WYP2
# WYP2_TGGAACAAGCCAAGACCCGACAAC #B45B5D       WYP2  #B45B5D      WYP2
# WYP2_TGGAACAAGCTAACGAACGTATCA #B45B5D       WYP2  #B45B5D      WYP2
# WYP2_TGGAACAATCTTCACAATGCCTAA #B45B5D       WYP2  #B45B5D      WYP2
# WYP2_TGGCTTCAAATGTTGCGTGTTCTA #B45B5D       WYP2  #B45B5D      WYP2
# WYP2_TGGCTTCAACCACTGTAGATCGCA #B45B5D       WYP2  #B45B5D      WYP2
# WYP2_TGGCTTCAATTGGCTCCGCATACA #B45B5D       WYP2  #B45B5D      WYP2
# WYP2_TGGCTTCACATCAAGTGCCAAGAC #B45B5D       WYP2  #B45B5D      WYP2
# WYP2_TGGCTTCACCGAAGTAAAGAGATC #B45B5D       WYP2  #B45B5D      WYP2
# WYP2_TGGCTTCACTAAGGTCAACAACCA #B45B5D       WYP2  #B45B5D      WYP2
# WYP2_TGGCTTCAGAGCTGAACCTCCTGA #B45B5D       WYP2  #B45B5D      WYP2
# WYP2_TGGCTTCAGATGAATCATTGGCTC #B45B5D       WYP2  #B45B5D      WYP2
# WYP2_TGGTGGTAAAACATCGAACGTGAT #B45B5D       WYP2  #B45B5D      WYP2
# WYP2_TGGTGGTAAATCCGTCGTACGCAA #B45B5D       WYP2  #B45B5D      WYP2
# WYP2_TGGTGGTAACAGATTCCACTTCGA #B45B5D       WYP2  #B45B5D      WYP2
# WYP2_TGGTGGTAACATTGGCAGCAGGAA #B45B5D       WYP2  #B45B5D      WYP2
# WYP2_TGGTGGTAAGAGTCAAAGCCATGC #B45B5D       WYP2  #B45B5D      WYP2
# WYP2_TGGTGGTAAGTGGTCACCAGTTCA #B45B5D       WYP2  #B45B5D      WYP2
# WYP2_TGGTGGTAATCATTCCAATGTTGC #B45B5D       WYP2  #B45B5D      WYP2
# WYP2_TGGTGGTAATCCTGTACTGGCATA #B45B5D       WYP2  #B45B5D      WYP2
# WYP2_TGGTGGTACAAGGAGCCCTCCTGA #B45B5D       WYP2  #B45B5D      WYP2
# WYP2_TGGTGGTACCGACAACCTGAGCCA #B45B5D       WYP2  #B45B5D      WYP2
# WYP2_TGGTGGTACTCAATGACGCTGATC #B45B5D       WYP2  #B45B5D      WYP2
# WYP2_TGGTGGTACTCAATGACTGGCATA #B45B5D       WYP2  #B45B5D      WYP2
# WYP2_TGGTGGTAGAGCTGAAGAATCTGA #B45B5D       WYP2  #B45B5D      WYP2
# WYP2_TGGTGGTAGCGAGTAAACCACTGT #B45B5D       WYP2  #B45B5D      WYP2
# WYP2_TTCACGCACTCAATGAAGTCACTA #B45B5D       WYP2  #B45B5D      WYP2
# WYP2_TTCACGCAGAGCTGAAACGCTCGA #B45B5D       WYP2  #B45B5D      WYP2
# WYP2_TTCACGCATGGCTTCAACAGATTC #B45B5D       WYP2  #B45B5D      WYP2
# WYP2_TTCACGCATGGTGGTACACTTCGA #B45B5D       WYP2  #B45B5D      WYP2
#                               platform percent.mt ⋯ raw_cluster_colors louvain
# WYP0_AAACATCGAACGTGATCCGACAAC A        5.132133   ⋯ #FF1F1D            4
# WYP0_AAACATCGAAGGACACTTCACGCA A        9.682978   ⋯ #FF8AB6            7
# WYP0_AAACATCGACACGACCAGTGGTCA A        8.909042   ⋯ #0067AA            1
# WYP0_AAACATCGACCACTGTAACTCACC A        9.379862   ⋯ #0067AA            1
# WYP0_AAACATCGACCACTGTAAGAGATC A        6.257089   ⋯ #0067AA            1
# WYP0_AAACATCGAGGCTAACCATACCAA A        9.236603   ⋯ #FF1F1D            4
# WYP0_AAACATCGAGTGGTCAAATCCGTC A        5.226379   ⋯ #0067AA            1
# WYP0_AAACATCGATAGCGACATCATTCC A        4.895215   ⋯ #0067AA            1
# WYP0_AAACATCGATCATTCCGACTAGTA A        7.900208   ⋯ #0067AA            1
# WYP0_AAACATCGATCCTGTACCAGTTCA A        7.706331   ⋯ #FF8AB6            7
# WYP0_AAACATCGCACCTTACCACCTTAC A        7.318359   ⋯ #FF1F1D            4
# WYP0_AAACATCGCACCTTACCCGAAGTA A        7.515134   ⋯ #0067AA            1
# WYP0_AAACATCGCACTTCGAACAGATTC A        9.886650   ⋯ #FF1F1D            4
# WYP0_AAACATCGCAGATCTGTCTTCACA A        8.671789   ⋯ #FF1F1D            4
# WYP0_AAACATCGCCAGTTCACATCAAGT A        7.041262   ⋯ #0067AA            1
# WYP0_AAACATCGCCGACAACCCATCCTC A        8.095326   ⋯ #FF1F1D            4
# WYP0_AAACATCGCCGACAACCGACTGGA A        5.946944   ⋯ #FF1F1D            4
# WYP0_AAACATCGCCTAATCCAATGTTGC A        8.463593   ⋯ #85D5F8            10
# WYP0_AAACATCGCGCTGATCCAACCACA A        8.721846   ⋯ #FF8AB6            7
# WYP0_AAACATCGCTAAGGTCAGTACAAG A        6.832034   ⋯ #FF1F1D            4
# WYP0_AAACATCGGACAGTGCAACGTGAT A        5.611441   ⋯ #FF1F1D            4
# WYP0_AAACATCGGAGCTGAACCTAATCC A        5.300315   ⋯ #FF8AB6            7
# WYP0_AAACATCGGTACGCAAAGCACCTC A        7.810377   ⋯ #FF8AB6            7
# WYP0_AAACATCGGTGTTCTAAGAGTCAA A        4.023155   ⋯ #0067AA            1
# WYP0_AAACATCGGTGTTCTACTGAGCCA A        7.543809   ⋯ #FF1F1D            4
# WYP0_AAACATCGTATCAGCAATTGGCTC A        6.040965   ⋯ #0067AA            1
# WYP0_AACAACCAAAACATCGGGTGCGAA A        7.529411   ⋯ #FF1F1D            4
# WYP0_AACAACCAAACAACCAGAATCTGA A        7.332007   ⋯ #FF1F1D            4
# WYP0_AACAACCAAACGCTTAAGTCACTA A        8.663900   ⋯ #0067AA            1
# WYP0_AACAACCAAAGACGGAAACTCACC A        7.264075   ⋯ #FF1F1D            4
# ⋮                             ⋮        ⋮          ⋱ ⋮                  ⋮
# WYP2_TGGAACAACCTCCTGAACCACTGT A        6.119856   ⋯ #0067AA            1
# WYP2_TGGAACAAGCCAAGACCCGACAAC A        4.929577   ⋯ #0067AA            1
# WYP2_TGGAACAAGCTAACGAACGTATCA A        6.120024   ⋯ #0067AA            1
# WYP2_TGGAACAATCTTCACAATGCCTAA A        5.262216   ⋯ #0067AA            1
# WYP2_TGGCTTCAAATGTTGCGTGTTCTA A        5.558525   ⋯ #0067AA            1
# WYP2_TGGCTTCAACCACTGTAGATCGCA A        6.813793   ⋯ #0067AA            1
# WYP2_TGGCTTCAATTGGCTCCGCATACA A        7.631739   ⋯ #0067AA            1
# WYP2_TGGCTTCACATCAAGTGCCAAGAC A        9.392265   ⋯ #0067AA            1
# WYP2_TGGCTTCACCGAAGTAAAGAGATC A        6.320125   ⋯ #0067AA            1
# WYP2_TGGCTTCACTAAGGTCAACAACCA A        7.056517   ⋯ #0067AA            1
# WYP2_TGGCTTCAGAGCTGAACCTCCTGA A        5.181986   ⋯ #0067AA            1
# WYP2_TGGCTTCAGATGAATCATTGGCTC A        6.273569   ⋯ #0067AA            1
# WYP2_TGGTGGTAAAACATCGAACGTGAT A        5.571031   ⋯ #0067AA            1
# WYP2_TGGTGGTAAATCCGTCGTACGCAA A        6.634358   ⋯ #0067AA            1
# WYP2_TGGTGGTAACAGATTCCACTTCGA A        9.781620   ⋯ #0067AA            1
# WYP2_TGGTGGTAACATTGGCAGCAGGAA A        7.620278   ⋯ #0067AA            1
# WYP2_TGGTGGTAAGAGTCAAAGCCATGC A        5.231037   ⋯ #0067AA            1
# WYP2_TGGTGGTAAGTGGTCACCAGTTCA A        8.636149   ⋯ #0067AA            1
# WYP2_TGGTGGTAATCATTCCAATGTTGC A        5.685131   ⋯ #0067AA            1
# WYP2_TGGTGGTAATCCTGTACTGGCATA A        9.516129   ⋯ #0067AA            1
# WYP2_TGGTGGTACAAGGAGCCCTCCTGA A        7.121364   ⋯ #0067AA            1
# WYP2_TGGTGGTACCGACAACCTGAGCCA A        5.103970   ⋯ #FF8AB6            7
# WYP2_TGGTGGTACTCAATGACGCTGATC A        5.166965   ⋯ #85D5F8            10
# WYP2_TGGTGGTACTCAATGACTGGCATA A        7.852808   ⋯ #0067AA            1
# WYP2_TGGTGGTAGAGCTGAAGAATCTGA A        8.608059   ⋯ #0067AA            1
# WYP2_TGGTGGTAGCGAGTAAACCACTGT A        6.035731   ⋯ #0067AA            1
# WYP2_TTCACGCACTCAATGAAGTCACTA A        7.185355   ⋯ #0067AA            1
# WYP2_TTCACGCAGAGCTGAAACGCTCGA A        5.400697   ⋯ #0067AA            1
# WYP2_TTCACGCATGGCTTCAACAGATTC A        5.398458   ⋯ #0067AA            1
# WYP2_TTCACGCATGGTGGTACACTTCGA A        7.478368   ⋯ #0067AA            1
#                               seurat_cluster car  RNA_snn_res.0.8
# WYP0_AAACATCGAACGTGATCCGACAAC 4              CAR+ 5
# WYP0_AAACATCGAAGGACACTTCACGCA 7              CAR+ 5
# WYP0_AAACATCGACACGACCAGTGGTCA 1              CAR+ 1
# WYP0_AAACATCGACCACTGTAACTCACC 1              CAR+ 1
# WYP0_AAACATCGACCACTGTAAGAGATC 1              CAR+ 1
# WYP0_AAACATCGAGGCTAACCATACCAA 4              CAR+ 5
# WYP0_AAACATCGAGTGGTCAAATCCGTC 1              CAR+ 1
# WYP0_AAACATCGATAGCGACATCATTCC 1              CAR+ 1
# WYP0_AAACATCGATCATTCCGACTAGTA 1              CAR+ 1
# WYP0_AAACATCGATCCTGTACCAGTTCA 7              CAR+ 5
# WYP0_AAACATCGCACCTTACCACCTTAC 4              CAR+ 5
# WYP0_AAACATCGCACCTTACCCGAAGTA 1              CAR+ 1
# WYP0_AAACATCGCACTTCGAACAGATTC 4              CAR+ 5
# WYP0_AAACATCGCAGATCTGTCTTCACA 4              CAR+ 5
# WYP0_AAACATCGCCAGTTCACATCAAGT 1              CAR+ 1
# WYP0_AAACATCGCCGACAACCCATCCTC 4              CAR+ 5
# WYP0_AAACATCGCCGACAACCGACTGGA 4              CAR+ 5
# WYP0_AAACATCGCCTAATCCAATGTTGC 10             CAR+ 1
# WYP0_AAACATCGCGCTGATCCAACCACA 7              CAR+ 5
# WYP0_AAACATCGCTAAGGTCAGTACAAG 4              CAR+ 2
# WYP0_AAACATCGGACAGTGCAACGTGAT 4              CAR+ 5
# WYP0_AAACATCGGAGCTGAACCTAATCC 7              CAR+ 1
# WYP0_AAACATCGGTACGCAAAGCACCTC 7              CAR+ 1
# WYP0_AAACATCGGTGTTCTAAGAGTCAA 1              CAR+ 1
# WYP0_AAACATCGGTGTTCTACTGAGCCA 4              CAR+ 5
# WYP0_AAACATCGTATCAGCAATTGGCTC 1              CAR+ 1
# WYP0_AACAACCAAAACATCGGGTGCGAA 4              CAR+ 5
# WYP0_AACAACCAAACAACCAGAATCTGA 4              CAR+ 5
# WYP0_AACAACCAAACGCTTAAGTCACTA 1              CAR+ 1
# WYP0_AACAACCAAAGACGGAAACTCACC 4              CAR+ 5
# ⋮                             ⋮              ⋮    ⋮
# WYP2_TGGAACAACCTCCTGAACCACTGT 1              CAR+ 10
# WYP2_TGGAACAAGCCAAGACCCGACAAC 1              CAR+ 8
# WYP2_TGGAACAAGCTAACGAACGTATCA 1              CAR+ 10
# WYP2_TGGAACAATCTTCACAATGCCTAA 1              CAR+ 10
# WYP2_TGGCTTCAAATGTTGCGTGTTCTA 1              CAR+ 10
# WYP2_TGGCTTCAACCACTGTAGATCGCA 1              CAR+ 10
# WYP2_TGGCTTCAATTGGCTCCGCATACA 1              CAR+ 10
# WYP2_TGGCTTCACATCAAGTGCCAAGAC 1              CAR+ 10
# WYP2_TGGCTTCACCGAAGTAAAGAGATC 1              CAR+ 10
# WYP2_TGGCTTCACTAAGGTCAACAACCA 1              CAR+ 10
# WYP2_TGGCTTCAGAGCTGAACCTCCTGA 1              CAR+ 10
# WYP2_TGGCTTCAGATGAATCATTGGCTC 1              CAR+ 10
# WYP2_TGGTGGTAAAACATCGAACGTGAT 1              CAR+ 10
# WYP2_TGGTGGTAAATCCGTCGTACGCAA 1              CAR+ 10
# WYP2_TGGTGGTAACAGATTCCACTTCGA 1              CAR+ 10
# WYP2_TGGTGGTAACATTGGCAGCAGGAA 1              CAR+ 10
# WYP2_TGGTGGTAAGAGTCAAAGCCATGC 1              CAR+ 10
# WYP2_TGGTGGTAAGTGGTCACCAGTTCA 1              CAR+ 10
# WYP2_TGGTGGTAATCATTCCAATGTTGC 1              CAR+ 10
# WYP2_TGGTGGTAATCCTGTACTGGCATA 1              CAR+ 10
# WYP2_TGGTGGTACAAGGAGCCCTCCTGA 1              CAR+ 10
# WYP2_TGGTGGTACCGACAACCTGAGCCA 7              CAR+ 9
# WYP2_TGGTGGTACTCAATGACGCTGATC 10             CAR+ 12
# WYP2_TGGTGGTACTCAATGACTGGCATA 1              CAR+ 10
# WYP2_TGGTGGTAGAGCTGAAGAATCTGA 1              CAR+ 10
# WYP2_TGGTGGTAGCGAGTAAACCACTGT 1              CAR+ 10
# WYP2_TTCACGCACTCAATGAAGTCACTA 1              CAR+ 8
# WYP2_TTCACGCAGAGCTGAAACGCTCGA 1              CAR+ 10
# WYP2_TTCACGCATGGCTTCAACAGATTC 1              CAR+ 10
# WYP2_TTCACGCATGGTGGTACACTTCGA 1              CAR+ 10
#                               seurat_clusters celltype       Size_Factor
# WYP0_AAACATCGAACGTGATCCGACAAC 5               CD8_Tcm        1.3147643
# WYP0_AAACATCGAAGGACACTTCACGCA 5               CD8_Tcm        3.4096925
# WYP0_AAACATCGACACGACCAGTGGTCA 1               CD4_Normal_Tcm 0.6292674
# WYP0_AAACATCGACCACTGTAACTCACC 1               CD4_Normal_Tcm 0.7551544
# WYP0_AAACATCGACCACTGTAAGAGATC 1               CD4_Normal_Tcm 0.8879233
# WYP0_AAACATCGAGGCTAACCATACCAA 5               CD8_Tcm        2.3460309
# WYP0_AAACATCGAGTGGTCAAATCCGTC 1               CD4_Normal_Tcm 1.1529574
# WYP0_AAACATCGATAGCGACATCATTCC 1               CD4_Normal_Tcm 1.0732290
# WYP0_AAACATCGATCATTCCGACTAGTA 1               CD4_Normal_Tcm 0.8073556
# WYP0_AAACATCGATCCTGTACCAGTTCA 5               CD8_Tcm        3.0384096
# WYP0_AAACATCGCACCTTACCACCTTAC 5               CD8_Tcm        2.2270257
# WYP0_AAACATCGCACCTTACCCGAAGTA 1               CD4_Normal_Tcm 1.1368439
# WYP0_AAACATCGCACTTCGAACAGATTC 5               CD8_Tcm        1.5992690
# WYP0_AAACATCGCAGATCTGTCTTCACA 5               CD8_Tcm        3.9756806
# WYP0_AAACATCGCCAGTTCACATCAAGT 1               CD4_Normal_Tcm 1.1918985
# WYP0_AAACATCGCCGACAACCCATCCTC 5               CD8_Tcm        1.8100878
# WYP0_AAACATCGCCGACAACCGACTGGA 5               CD8_Tcm        1.7273381
# WYP0_AAACATCGCCTAATCCAATGTTGC 1               CD4_Normal_Tcm 2.9529743
# WYP0_AAACATCGCGCTGATCCAACCACA 5               CD8_Tcm        2.4517760
# WYP0_AAACATCGCTAAGGTCAGTACAAG 2               CD4_Blood_Tcm  1.1841774
# WYP0_AAACATCGGACAGTGCAACGTGAT 5               CD8_Tcm        1.3849253
# WYP0_AAACATCGGAGCTGAACCTAATCC 1               CD4_Normal_Tcm 1.5453893
# WYP0_AAACATCGGTACGCAAAGCACCTC 1               CD4_Normal_Tcm 1.2357072
# WYP0_AAACATCGGTGTTCTAAGAGTCAA 1               CD4_Normal_Tcm 0.5799196
# WYP0_AAACATCGGTGTTCTACTGAGCCA 5               CD8_Tcm        2.9214186
# WYP0_AAACATCGTATCAGCAATTGGCTC 1               CD4_Normal_Tcm 0.6473951
# WYP0_AACAACCAAAACATCGGGTGCGAA 5               CD8_Tcm        1.0700399
# WYP0_AACAACCAAACAACCAGAATCTGA 5               CD8_Tcm        1.0965601
# WYP0_AACAACCAAACGCTTAAGTCACTA 1               CD4_Normal_Tcm 1.0112926
# WYP0_AACAACCAAAGACGGAAACTCACC 5               CD8_Tcm        1.8693386
# ⋮                             ⋮               ⋮              ⋮
# WYP2_TGGAACAACCTCCTGAACCACTGT 10              CD8_Tem        2.3779223
# WYP2_TGGAACAAGCCAAGACCCGACAAC 8               CD8_Tem        0.5958653
# WYP2_TGGAACAAGCTAACGAACGTATCA 10              CD8_Tem        0.5649810
# WYP2_TGGAACAATCTTCACAATGCCTAA 10              CD8_Tem        0.9377745
# WYP2_TGGCTTCAAATGTTGCGTGTTCTA 10              CD8_Tem        0.6280924
# WYP2_TGGCTTCAACCACTGTAGATCGCA 10              CD8_Tem        0.6084540
# WYP2_TGGCTTCAATTGGCTCCGCATACA 10              CD8_Tem        0.5542387
# WYP2_TGGCTTCACATCAAGTGCCAAGAC 10              CD8_Tem        0.8202800
# WYP2_TGGCTTCACCGAAGTAAAGAGATC 10              CD8_Tem        1.1818275
# WYP2_TGGCTTCACTAAGGTCAACAACCA 10              CD8_Tem        0.5137870
# WYP2_TGGCTTCAGAGCTGAACCTCCTGA 10              CD8_Tem        0.5441677
# WYP2_TGGCTTCAGATGAATCATTGGCTC 10              CD8_Tem        0.4896167
# WYP2_TGGTGGTAAAACATCGAACGTGAT 10              CD8_Tem        0.6025793
# WYP2_TGGTGGTAAATCCGTCGTACGCAA 10              CD8_Tem        1.0044107
# WYP2_TGGTGGTAACAGATTCCACTTCGA 10              CD8_Tem        0.7378659
# WYP2_TGGTGGTAACATTGGCAGCAGGAA 10              CD8_Tem        0.5198296
# WYP2_TGGTGGTAAGAGTCAAAGCCATGC 10              CD8_Tem        0.5775697
# WYP2_TGGTGGTAAGTGGTCACCAGTTCA 10              CD8_Tem        0.7113457
# WYP2_TGGTGGTAATCATTCCAATGTTGC 10              CD8_Tem        1.1514468
# WYP2_TGGTGGTAATCCTGTACTGGCATA 10              CD8_Tem        0.5203331
# WYP2_TGGTGGTACAAGGAGCCCTCCTGA 10              CD8_Tem        0.6693834
# WYP2_TGGTGGTACCGACAACCTGAGCCA 9               CD8_Tem        1.8646389
# WYP2_TGGTGGTACTCAATGACGCTGATC 12              CD8_Teff       1.9653485
# WYP2_TGGTGGTACTCAATGACTGGCATA 10              CD8_Tem        0.4424510
# WYP2_TGGTGGTAGAGCTGAAGAATCTGA 10              CD8_Tem        0.5498746
# WYP2_TGGTGGTAGCGAGTAAACCACTGT 10              CD8_Tem        0.6952322
# WYP2_TTCACGCACTCAATGAAGTCACTA 8               CD8_Tem        0.7335018
# WYP2_TTCACGCAGAGCTGAAACGCTCGA 10              CD8_Tem        0.7707644
# WYP2_TTCACGCATGGCTTCAACAGATTC 10              CD8_Tem        1.1752814
# WYP2_TTCACGCATGGTGGTACACTTCGA 10              CD8_Tem        0.5431606
#                               Pseudotime State
# WYP0_AAACATCGAACGTGATCCGACAAC  2.5085717 1
# WYP0_AAACATCGAAGGACACTTCACGCA  0.2309998 1
# WYP0_AAACATCGACACGACCAGTGGTCA 10.3290190 5
# WYP0_AAACATCGACCACTGTAACTCACC 10.5263211 5
# WYP0_AAACATCGACCACTGTAAGAGATC 10.5220136 5
# WYP0_AAACATCGAGGCTAACCATACCAA  0.5427694 1
# WYP0_AAACATCGAGTGGTCAAATCCGTC 10.5120433 5
# WYP0_AAACATCGATAGCGACATCATTCC 10.4913760 5
# WYP0_AAACATCGATCATTCCGACTAGTA 10.5237245 5
# WYP0_AAACATCGATCCTGTACCAGTTCA  0.4968542 1
# WYP0_AAACATCGCACCTTACCACCTTAC  0.6242165 1
# WYP0_AAACATCGCACCTTACCCGAAGTA  6.1974312 1
# WYP0_AAACATCGCACTTCGAACAGATTC  2.8881415 1
# WYP0_AAACATCGCAGATCTGTCTTCACA  0.3786212 1
# WYP0_AAACATCGCCAGTTCACATCAAGT 10.5295567 5
# WYP0_AAACATCGCCGACAACCCATCCTC  0.7429461 1
# WYP0_AAACATCGCCGACAACCGACTGGA  0.8181065 1
# WYP0_AAACATCGCCTAATCCAATGTTGC  2.7924417 1
# WYP0_AAACATCGCGCTGATCCAACCACA  0.4928464 1
# WYP0_AAACATCGCTAAGGTCAGTACAAG  5.0011308 1
# WYP0_AAACATCGGACAGTGCAACGTGAT  0.7197639 1
# WYP0_AAACATCGGAGCTGAACCTAATCC  2.7730826 1
# WYP0_AAACATCGGTACGCAAAGCACCTC  3.6167887 1
# WYP0_AAACATCGGTGTTCTAAGAGTCAA 10.5629744 5
# WYP0_AAACATCGGTGTTCTACTGAGCCA  0.5659667 1
# WYP0_AAACATCGTATCAGCAATTGGCTC 10.4940605 5
# WYP0_AACAACCAAAACATCGGGTGCGAA  0.3715031 1
# WYP0_AACAACCAAACAACCAGAATCTGA  3.0843595 1
# WYP0_AACAACCAAACGCTTAAGTCACTA 10.6682294 5
# WYP0_AACAACCAAAGACGGAAACTCACC  0.5339792 1
# ⋮                             ⋮          ⋮
# WYP2_TGGAACAACCTCCTGAACCACTGT 18.93221   3
# WYP2_TGGAACAAGCCAAGACCCGACAAC 17.54917   4
# WYP2_TGGAACAAGCTAACGAACGTATCA 17.46428   4
# WYP2_TGGAACAATCTTCACAATGCCTAA 17.70530   4
# WYP2_TGGCTTCAAATGTTGCGTGTTCTA 17.50302   4
# WYP2_TGGCTTCAACCACTGTAGATCGCA 17.50412   4
# WYP2_TGGCTTCAATTGGCTCCGCATACA 17.52274   4
# WYP2_TGGCTTCACATCAAGTGCCAAGAC 17.50571   4
# WYP2_TGGCTTCACCGAAGTAAAGAGATC 17.48440   4
# WYP2_TGGCTTCACTAAGGTCAACAACCA 17.44005   4
# WYP2_TGGCTTCAGAGCTGAACCTCCTGA 17.38372   4
# WYP2_TGGCTTCAGATGAATCATTGGCTC 17.34843   4
# WYP2_TGGTGGTAAAACATCGAACGTGAT 15.66922   2
# WYP2_TGGTGGTAAATCCGTCGTACGCAA 17.39946   4
# WYP2_TGGTGGTAACAGATTCCACTTCGA 15.34294   2
# WYP2_TGGTGGTAACATTGGCAGCAGGAA 17.30934   4
# WYP2_TGGTGGTAAGAGTCAAAGCCATGC 15.83276   2
# WYP2_TGGTGGTAAGTGGTCACCAGTTCA 17.55402   4
# WYP2_TGGTGGTAATCATTCCAATGTTGC 17.49865   4
# WYP2_TGGTGGTAATCCTGTACTGGCATA 17.23039   4
# WYP2_TGGTGGTACAAGGAGCCCTCCTGA 17.41384   4
# WYP2_TGGTGGTACCGACAACCTGAGCCA 21.36708   3
# WYP2_TGGTGGTACTCAATGACGCTGATC 25.08821   3
# WYP2_TGGTGGTACTCAATGACTGGCATA 17.33261   4
# WYP2_TGGTGGTAGAGCTGAAGAATCTGA 14.27450   2
# WYP2_TGGTGGTAGCGAGTAAACCACTGT 17.50381   4
# WYP2_TTCACGCACTCAATGAAGTCACTA 20.93367   3
# WYP2_TTCACGCAGAGCTGAAACGCTCGA 14.39815   2
# WYP2_TTCACGCATGGCTTCAACAGATTC 16.93553   4
# WYP2_TTCACGCATGGTGGTACACTTCGA 15.71111   2

# %%
plot_cell_trajectory(HSMM, color_by = "Pseudotime",cell_size = 1) +
  theme(legend.text = element_text(size=10),legend.background = element_rect(colour='black', size=1),
        legend.key.size = unit(50, "pt"))
# Out:
# plot without title

# %%
ggplot2::ggsave('/SGRNJ06/randd/USER/cjj/celedev/XZMU/20230213/wyp/pseudotime.png', height=10, width=10)

# %%
# 有时候（大多数时候），拟时序的方向或是根节点弄错了，还需要手动更改
HSMM=orderCells(HSMM,root_state = 2)

# %%
plot_cell_trajectory(HSMM, color_by = "Pseudotime",cell_size = 1) +
  theme(legend.text = element_text(size=10),legend.background = element_rect(colour='black', size=1),
        legend.key.size = unit(50, "pt"))
# Out:
# plot without title

# %%
ggplot2::ggsave('/SGRNJ06/randd/USER/cjj/celedev/XZMU/20230213/dyc/repseudotime.png', height=10, width=10)

# %%
plot_cell_trajectory(HSMM, color_by = "State",cell_size = 1.5) + 
  guides(colour = guide_legend(override.aes = list(size=4)))+
  theme(legend.text = element_text(size=15))+ scale_color_npg()
# Out:
# plot without title

# %%
ggplot2::ggsave('/SGRNJ06/randd/USER/cjj/celedev/XZMU/20230213/wyp/state.png', height=10, width=10)

# %%
plot_cell_trajectory(HSMM, color_by = "celltype",cell_size = 1.5) + 
  guides(colour = guide_legend(override.aes = list(size=4)))+
  theme(legend.text = element_text(size=15))+ scale_color_npg()
# Out:
# plot without title

# %%
ggplot2::ggsave('/SGRNJ06/randd/USER/cjj/celedev/XZMU/20230213/wyp/celltype.png', height=10, width=10)

# %%
plot_cell_trajectory(HSMM, color_by = "car",cell_size = 1.5) + 
  guides(colour = guide_legend(override.aes = list(size=4)))+
  theme(legend.text = element_text(size=15))+ scale_color_npg()
# Out:
# plot without title

# %%
ggplot2::ggsave('/SGRNJ06/randd/USER/cjj/celedev/XZMU/20230103/monocle/wyp/car.png', height=10, width=10)

# %%
##分离CAR+和CAR-
meta = HSMM@phenoData@data
write.table(meta,file="/SGRNJ06/randd/USER/cjj/celedev/XZMU/20230103/monocle/wyp//HSMMmeta.xls",sep = '\t',quote=F,row.names=T)

# %%
#文件中有-时 需要xls另存为csv文件
meta=read.csv("/SGRNJ06/randd/USER/cjj/celedev/XZMU/20230103/monocle/wyp/HSMMmeta.csv",header = T, row.names = 1)
HSMM@phenoData@data=meta

# %%
meta=read.table("/SGRNJ06/randd/USER/cjj/celedev/XZMU/20230103/monocle/wyp/HSMMmeta.xls")
HSMM@phenoData@data=meta

# %%
plot_cell_trajectory(HSMM, color_by = "sample",cell_size = 1) + 
  guides(colour = guide_legend(override.aes = list(size=4)))+
  theme(legend.text = element_text(size=15))+ scale_color_npg()
# Out:
# plot without title

# %%
ggplot2::ggsave('/SGRNJ06/randd/USER/cjj/celedev/XZMU/20230213/wyp/sample.png', height=10, width=10)

# %%
meta=read.table("/SGRNJ06/randd/USER/cjj/celedev/XZMU/20220923analysis/monocle/HSMMmeta.xls")
HSMM@phenoData@data=meta

# %%
show_col(pal_npg("nrc")(10))

# %%
target = c(pal_npg("nrc")(10)[8],pal_npg("nrc")(10)[2], pal_npg("nrc")(10)[3], pal_npg("nrc")(10)[4], pal_npg("nrc")(10)[5], pal_npg("nrc")(10)[6], pal_npg("nrc")(10)[7], pal_npg("nrc")(10)[9])

# %%
show_col(target)

# %%
plot_cell_trajectory(HSMM, color_by = "cluster",cell_size = 1) + 
  guides(colour = guide_legend(override.aes = list(size=4))) +
  theme(legend.text = element_text(size=15)) + scale_color_npg()
#+ scale_color_npg(palette = target, alpha = 0.8)
# Out:
# plot without title

# %%
ggplot2::ggsave('/SGRNJ06/randd/USER/cjj/celedev/XZMU/20230103/monocle/wyp/celltype_car.png', height=10, width=10)

# %%
meta = HSMM@phenoData@data

# %%
table(meta$State)
# Out:
#    1    2    3    4    5
# 5117  461 2678 3988 3114

# %%
plot_cell_trajectory(HSMM, color_by = "State")

plot_cell_trajectory(HSMM, color_by = "Pseudotime",cell_size = 1) +
  theme(legend.text = element_text(size=10),legend.background = element_rect(colour='black', size=1),
        legend.key.size = unit(50, "pt"))

plot_cell_trajectory(HSMM, color_by = "celltype",cell_size = 1.5) + 
  guides(colour = guide_legend(override.aes = list(size=4)))+
  theme(legend.text = element_text(size=15))+ scale_color_npg()

# %%
Idents(rds) <- "orig.ident"
rds0 = subset(rds,idents='GC_0_ZL')
rds1 = subset(rds,idents='GC_1_ZL')
rds2 = subset(rds,idents='GC_2_ZL')

# %%
Idents(rds0) <- 'car'
Idents(rds1) <- 'car'
Idents(rds2) <- 'car'
m1 = FindMarkers(object = rds0,ident.1 = 'CAR+')
m2 = FindMarkers(object = rds1,ident.1 = 'CAR+')
m3 = FindMarkers(object = rds2,ident.1 = 'CAR+')

# %%
write.table(m1,'/SGRNJ06/randd/USER/cjj/celedev/XZMU/20220923analysis/marker/gc0.tsv',sep='\t',quote=F,row.names=T)
write.table(m2,'/SGRNJ06/randd/USER/cjj/celedev/XZMU/20220923analysis/marker/gc1.tsv',sep='\t',quote=F,row.names=T)
write.table(m3,'/SGRNJ06/randd/USER/cjj/celedev/XZMU/20220923analysis/marker/gc2.tsv',sep='\t',quote=F,row.names=T)

# %%
m3

# %%
library('monocle')

# %%
sessionInfo()

# %%
rds@meta.data

# %%
Idents(rds) <- "orig.ident"
markers = FindAllMarkers(rds)

# %%
1+1
# Out:
# [1] 2

# %%
meta = HSMM@phenoData@data
write.table(meta,file="/SGRNJ06/randd/USER/cjj/celedev/XZMU/20221110/monocle/check.tsv",sep = '\t',quote=F,row.names=T)
