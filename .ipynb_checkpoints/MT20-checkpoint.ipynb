# %%
library(ggplot2)
library(reshape2)
library(argparser)
library(Seurat)
library(dplyr)
library(grid)
library(cowplot)
library(dplyr)
library(grid)
library(tidyverse)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Registered S3 method overwritten by 'cli':
#   method     from
#   print.boxx spatstat.geom
#
# ── Attaching packages ──────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ tibble  3.1.0     ✔ purrr   0.3.4
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ─────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
RAW1 <- Read10X(data.dir = '/SGRNJ06/randd/USER/cjj/celedev/wanheyuan/20220901cr7_v3/QT-CA-T2202-040/03.cellranger/QT-CA-T2202-040/outs/filtered_feature_bc_matrix')

# %%
PRO1 <- CreateSeuratObject(counts = RAW1, project = 'test', min.cells = 5)

# %%
PRO1
# Out:
# An object of class Seurat
# 20901 features across 10967 samples within 1 assay
# Active assay: RNA (20901 features, 0 variable features)

# %%
PRO1 <- RenameCells(PRO1, add.cell.id = 'test')
PRO1@meta.data$sample <- 'test'
PRO1[["percent.mt"]] <- PercentageFeatureSet(PRO1, pattern = "^MT-")

# %%
table(PRO1@meta.data$percent.mt > 20)
# Out:
# FALSE  TRUE
#  8845  2122

# %%
PRO1@meta.data
# Out:
#                         orig.ident nCount_RNA nFeature_RNA sample percent.mt
# test_AAACCCAAGAAACCCA-1 test         870       523         test    7.7011494
# test_AAACCCAAGAAACCCG-1 test        1878       743         test   23.2694356
# test_AAACCCAAGAAACCTG-1 test        1466       778         test    0.7503411
# test_AAACCCAAGAAACGAA-1 test        3914      1479         test   16.3260092
# test_AAACCCAAGAAACTAC-1 test        1624       764         test    3.7561576
# test_AAACCCAAGAAACTCA-1 test        1415       779         test   10.2473498
# test_AAACCCAAGAAACTGC-1 test         720       289         test   54.0277778
# test_AAACCCAAGAAAGACA-1 test        2611      1182         test    8.6939870
# test_AAACCCAAGAAAGCCT-1 test         908       464         test   12.5550661
# test_AAACCCAAGAAAGCGA-1 test         943       548         test    8.0593849
# test_AAACCCAAGAAAGGAT-1 test         655       361         test    7.1755725
# test_AAACCCAAGAAAGGTA-1 test        3788      1400         test   14.4931362
# test_AAACCCAAGAAAGTCT-1 test         627       295         test   35.0877193
# test_AAACCCAAGAAATAGG-1 test         751       435         test   17.3102530
# test_AAACCCAAGAAATCCA-1 test        1060       686         test   10.4716981
# test_AAACCCAAGAAATGAG-1 test        1665       841         test   24.8648649
# test_AAACCCAAGAAATGCC-1 test        1935       950         test    7.3901809
# test_AAACCCAAGAACACCA-1 test        2160      1165         test    9.7685185
# test_AAACCCAAGAACAGGA-1 test        1498       731         test    6.5420561
# test_AAACCCAAGAACCCGA-1 test        2486       915         test   14.6822204
# test_AAACCCAAGAACCGAT-1 test        6551      2073         test    7.9224546
# test_AAACCCAAGAACCTCC-1 test        3340      1577         test    6.4670659
# test_AAACCCAAGAACCTTT-1 test        1011       509         test   28.3877349
# test_AAACCCAAGAACGAGG-1 test        2397      1240         test    3.4626617
# test_AAACCCAAGAACGCGT-1 test       15633      4381         test    1.4200729
# test_AAACCCAAGAACTACG-1 test        1777       715         test   19.6961171
# test_AAACCCAAGAACTCCT-1 test         621       310         test   39.9355878
# test_AAACCCAAGAACTCTT-1 test         889       529         test    9.4488189
# test_AAACCCAAGAACTGAT-1 test        2547      1230         test    6.6745190
# test_AAACCCAAGAACTGGT-1 test        1655       847         test    8.2175227
# ⋮                       ⋮          ⋮          ⋮            ⋮      ⋮
# test_AACAAGATCGGCAGGA-1 test        740       491          test   10.270270
# test_AACAAGATCGGTCTAA-1 test        637       363          test   18.210361
# test_AACAAGATCTCCTGTG-1 test        779       404          test   13.863928
# test_AACACACAGGAACTAT-1 test        809       536          test    8.652658
# test_AACACACCAAAGCTAA-1 test       1219       674          test    7.465135
# test_AACACACCAAAGTAGT-1 test        794       500          test   11.083123
# test_AACACACCAACTCCGG-1 test        609       386          test    8.374384
# test_AACACACCACGAAGCA-1 test        668       451          test    8.682635
# test_AACACACCACGCCAGT-1 test        912       457          test    8.223684
# test_AACACACCAGAAGTTA-1 test        646       446          test    7.120743
# test_AACACACGTAGACGTG-1 test        860       571          test    7.906977
# test_AACACACGTTCGAACT-1 test        945       577          test    8.359788
# test_AACACACTCCAGGACC-1 test        502       351          test    5.378486
# test_AACAGGGAGCTCTAAT-1 test        911       578          test    7.683864
# test_AACAGGGAGTCGAAGC-1 test       1436       851          test    4.874652
# test_AACAGGGCACACTACA-1 test        675       429          test   14.814815
# test_AACAGGGCAGCGGTAA-1 test        660       422          test   13.636364
# test_AACAGGGGTAGGAGGG-1 test        833       566          test    7.082833
# test_AACAGGGGTTAGAATG-1 test        650       399          test    3.230769
# test_AACAGGGTCATTGAGC-1 test        689       484          test    1.741655
# test_AACAGGGTCTCAGGGT-1 test       1074       697          test    8.472998
# test_AACCAACAGGGTGTTA-1 test        695       504          test    5.035971
# test_AACCAACAGGTAGTGT-1 test        643       420          test   14.618974
# test_AACCAACCACACCTTC-1 test       1028       614          test    6.906615
# test_AACCAACCAGTTCATG-1 test        687       425          test    7.569141
# test_AACCAACTCATTACGG-1 test        725       452          test   10.758621
# test_AACCACACAGGTCTAT-1 test        608       415          test   10.032895
# test_AACCATGAGCGATAGT-1 test        785       450          test   10.700637
# test_AACCCAAGTTACAGCT-1 test        710       455          test    7.746479
# test_AACCTGAAGTAGGCAT-1 test        513       415          test    6.627680
