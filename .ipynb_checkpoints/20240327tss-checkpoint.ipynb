# %%
    library(Signac)
    library(Seurat)
    library(EnsDb.Mmusculus.v79)
    library(EnsDb.Hsapiens.v86)
    library(GenomicRanges)
    library(future)
    library(ggplot2)

# %%
counts <- Read10X_h5("/SGRNJ06/randd/PROJECT/scATAC/self_pipe/20240407_K562_3T3_824_sc_rr/A0326_4_3K_NOchendian_WXne_8242nd_D02SDS_T7_EDTA5030/outs/A0326_4_3K_NOchendian_WXne_8242nd_D02SDS_T7_EDTA5030_filtered_peak_count.h5")
metadata <- read.csv(
  file = "/SGRNJ06/randd/PROJECT/scATAC/self_pipe/20240407_K562_3T3_824_sc_rr/A0326_4_3K_NOchendian_WXne_8242nd_D02SDS_T7_EDTA5030/outs/cell_qc_metrics.tsv",
  header = TRUE,
  row.names = 1,
  sep='\t'
)

brain_assay <- CreateChromatinAssay(
  counts = counts,
  sep = c(":", "-"),
  #genome = "mm10",
  min.cells = 0,
  min.features = 0,
  fragments = '/SGRNJ06/randd/PROJECT/scATAC/self_pipe/20240407_K562_3T3_824_sc_rr/A0326_4_3K_NOchendian_WXne_8242nd_D02SDS_T7_EDTA5030/outs/fragments_corrected_dedup_count.tsv.gz',
)
# Out:
# Warning message:
# "Feature names cannot have underscores ('_'), replacing with dashes ('-')"
# Computing hash

# %%
brain <- CreateSeuratObject(
  counts = brain_assay,
  assay = 'peaks',
  project = 'ATAC',
  meta.data = metadata
)
# Out:
# Warning message in CreateSeuratObject.Assay(counts = brain_assay, assay = "peaks", :
# "Some cells in meta.data not present in provided counts matrix."
# Warning message:
# "Keys should be one or more alphanumeric characters followed by an underscore, setting key from peaks to peaks_"

# %%
granges(brain)
# Out:
# GRanges object with 171486 ranges and 0 metadata columns:
#                     seqnames            ranges strand
#                        <Rle>         <IRanges>  <Rle>
#        [1] GRCh38_GL000008.2     113589-113773      *
#        [2] GRCh38_GL000008.2     136870-137250      *
#        [3] GRCh38_GL000008.2     170154-170309      *
#        [4] GRCh38_GL000008.2       83126-83409      *
#        [5] GRCh38_GL000009.2     124418-125148      *
#        ...               ...               ...    ...
#   [171482]         mm10_chrY 90744350-90744588      *
#   [171483]         mm10_chrY 90804782-90805242      *
#   [171484]         mm10_chrY 90808771-90808906      *
#   [171485]         mm10_chrY 90825374-90825689      *
#   [171486]         mm10_chrY 90828491-90829013      *
#   -------
#   seqinfo: 100 sequences from an unspecified genome; no seqlengths

# %%
# extract gene annotations from EnsDb
annotations <- GetGRangesFromEnsDb(ensdb = EnsDb.Mmusculus.v79, verbose = FALSE)

# change to UCSC style since the data was mapped to hg19
seqlevels(annotations) <- paste0('chr', seqlevels(annotations))
genome(annotations) <- "mm10"

# add the gene information to the object
Annotation(brain) <- annotations

# %%
# extract gene annotations from EnsDb
annotations <- GetGRangesFromEnsDb(ensdb = EnsDb.Mmusculus.v79)
annotations1 <- GetGRangesFromEnsDb(ensdb = EnsDb.Hsapiens.v86)

# %%
# change to UCSC style since the data was mapped to hg19
seqlevels(annotations) <- paste0('mm10_chr', seqlevels(annotations))
genome(annotations) <- "mm10"
seqlevels(annotations1) <- paste0('GRCh38_chr', seqlevels(annotations1))
genome(annotations1) <- "hg38"

# %%
annotations
# Out:
# GRanges object with 1763965 ranges and 5 metadata columns:
#                        seqnames          ranges strand |              tx_id
#                           <Rle>       <IRanges>  <Rle> |        <character>
#   ENSMUSE00001236884  mm10_chr3 3508030-3508332      + | ENSMUST00000108393
#   ENSMUSE00000676606  mm10_chr3 3634150-3634347      + | ENSMUST00000108394
#   ENSMUSE00001345708  mm10_chr3 3638059-3638230      + | ENSMUST00000108393
#   ENSMUSE00001345708  mm10_chr3 3638059-3638230      + | ENSMUST00000108394
#   ENSMUSE00000149313  mm10_chr3 3641223-3641317      + | ENSMUST00000108393
#                  ...        ...             ...    ... .                ...
#   ENSMUST00000082414 mm10_chrMT     10167-11544      + | ENSMUST00000082414
#   ENSMUST00000082418 mm10_chrMT     11742-13565      + | ENSMUST00000082418
#   ENSMUST00000082419 mm10_chrMT     13552-14070      - | ENSMUST00000082419
#   ENSMUST00000082421 mm10_chrMT     14145-15288      + | ENSMUST00000082421
#   ENSMUST00000084013 mm10_chrMT      9877-10173      + | ENSMUST00000084013
#                        gene_name            gene_id   gene_biotype     type
#                      <character>        <character>    <character> <factor>
#   ENSMUSE00001236884       Hnf4g ENSMUSG00000017688 protein_coding     exon
#   ENSMUSE00000676606       Hnf4g ENSMUSG00000017688 protein_coding     exon
#   ENSMUSE00001345708       Hnf4g ENSMUSG00000017688 protein_coding     exon
#   ENSMUSE00001345708       Hnf4g ENSMUSG00000017688 protein_coding     exon
#   ENSMUSE00000149313       Hnf4g ENSMUSG00000017688 protein_coding     exon
#                  ...         ...                ...            ...      ...
#   ENSMUST00000082414      mt-Nd4 ENSMUSG00000064363 protein_coding      cds
#   ENSMUST00000082418      mt-Nd5 ENSMUSG00000064367 protein_coding      cds
#   ENSMUST00000082419      mt-Nd6 ENSMUSG00000064368 protein_coding      cds
#   ENSMUST00000082421     mt-Cytb ENSMUSG00000064370 protein_coding      cds
#   ENSMUST00000084013     mt-Nd4l ENSMUSG00000065947 protein_coding      cds
#   -------
#   seqinfo: 22 sequences from mm10 genome

# %%
annotations1
# Out:
# GRanges object with 3021151 ranges and 5 metadata columns:
#                       seqnames        ranges strand |           tx_id
#                          <Rle>     <IRanges>  <Rle> |     <character>
#   ENSE00001489430  GRCh38_chrX 276322-276394      + | ENST00000399012
#   ENSE00001536003  GRCh38_chrX 276324-276394      + | ENST00000484611
#   ENSE00002160563  GRCh38_chrX 276353-276394      + | ENST00000430923
#   ENSE00001750899  GRCh38_chrX 281055-281121      + | ENST00000445062
#   ENSE00001489388  GRCh38_chrX 281192-281684      + | ENST00000381657
#               ...          ...           ...    ... .             ...
#   ENST00000361739 GRCh38_chrMT     7586-8269      + | ENST00000361739
#   ENST00000361789 GRCh38_chrMT   14747-15887      + | ENST00000361789
#   ENST00000361851 GRCh38_chrMT     8366-8572      + | ENST00000361851
#   ENST00000361899 GRCh38_chrMT     8527-9207      + | ENST00000361899
#   ENST00000362079 GRCh38_chrMT     9207-9990      + | ENST00000362079
#                     gene_name         gene_id   gene_biotype     type
#                   <character>     <character>    <character> <factor>
#   ENSE00001489430      PLCXD1 ENSG00000182378 protein_coding     exon
#   ENSE00001536003      PLCXD1 ENSG00000182378 protein_coding     exon
#   ENSE00002160563      PLCXD1 ENSG00000182378 protein_coding     exon
#   ENSE00001750899      PLCXD1 ENSG00000182378 protein_coding     exon
#   ENSE00001489388      PLCXD1 ENSG00000182378 protein_coding     exon
#               ...         ...             ...            ...      ...
#   ENST00000361739      MT-CO2 ENSG00000198712 protein_coding      cds
#   ENST00000361789      MT-CYB ENSG00000198727 protein_coding      cds
#   ENST00000361851     MT-ATP8 ENSG00000228253 protein_coding      cds
#   ENST00000361899     MT-ATP6 ENSG00000198899 protein_coding      cds
#   ENST00000362079      MT-CO3 ENSG00000198938 protein_coding      cds
#   -------
#   seqinfo: 25 sequences from hg38 genome

# %%
l3 = GRangesList(annotations,annotations1)

# %%
l3
# Out:
# GRangesList object of length 2:
# [[1]]
# GRanges object with 1763965 ranges and 5 metadata columns:
#                        seqnames          ranges strand |              tx_id
#                           <Rle>       <IRanges>  <Rle> |        <character>
#   ENSMUSE00001236884  mm10_chr3 3508030-3508332      + | ENSMUST00000108393
#   ENSMUSE00000676606  mm10_chr3 3634150-3634347      + | ENSMUST00000108394
#   ENSMUSE00001345708  mm10_chr3 3638059-3638230      + | ENSMUST00000108393
#   ENSMUSE00001345708  mm10_chr3 3638059-3638230      + | ENSMUST00000108394
#   ENSMUSE00000149313  mm10_chr3 3641223-3641317      + | ENSMUST00000108393
#                  ...        ...             ...    ... .                ...
#   ENSMUST00000082414 mm10_chrMT     10167-11544      + | ENSMUST00000082414
#   ENSMUST00000082418 mm10_chrMT     11742-13565      + | ENSMUST00000082418
#   ENSMUST00000082419 mm10_chrMT     13552-14070      - | ENSMUST00000082419
#   ENSMUST00000082421 mm10_chrMT     14145-15288      + | ENSMUST00000082421
#   ENSMUST00000084013 mm10_chrMT      9877-10173      + | ENSMUST00000084013
#                        gene_name            gene_id   gene_biotype     type
#                      <character>        <character>    <character> <factor>
#   ENSMUSE00001236884       Hnf4g ENSMUSG00000017688 protein_coding     exon
#   ENSMUSE00000676606       Hnf4g ENSMUSG00000017688 protein_coding     exon
#   ENSMUSE00001345708       Hnf4g ENSMUSG00000017688 protein_coding     exon
#   ENSMUSE00001345708       Hnf4g ENSMUSG00000017688 protein_coding     exon
#   ENSMUSE00000149313       Hnf4g ENSMUSG00000017688 protein_coding     exon
#                  ...         ...                ...            ...      ...
#   ENSMUST00000082414      mt-Nd4 ENSMUSG00000064363 protein_coding      cds
#   ENSMUST00000082418      mt-Nd5 ENSMUSG00000064367 protein_coding      cds
#   ENSMUST00000082419      mt-Nd6 ENSMUSG00000064368 protein_coding      cds
#   ENSMUST00000082421     mt-Cytb ENSMUSG00000064370 protein_coding      cds
#   ENSMUST00000084013     mt-Nd4l ENSMUSG00000065947 protein_coding      cds
#   -------
#   seqinfo: 47 sequences from 2 genomes (mm10, hg38)
#
# [[2]]
# GRanges object with 3021151 ranges and 5 metadata columns:
#                       seqnames        ranges strand |           tx_id
#                          <Rle>     <IRanges>  <Rle> |     <character>
#   ENSE00001489430  GRCh38_chrX 276322-276394      + | ENST00000399012
#   ENSE00001536003  GRCh38_chrX 276324-276394      + | ENST00000484611
#   ENSE00002160563  GRCh38_chrX 276353-276394      + | ENST00000430923
#   ENSE00001750899  GRCh38_chrX 281055-281121      + | ENST00000445062
#   ENSE00001489388  GRCh38_chrX 281192-281684      + | ENST00000381657
#               ...          ...           ...    ... .             ...
#   ENST00000361739 GRCh38_chrMT     7586-8269      + | ENST00000361739
#   ENST00000361789 GRCh38_chrMT   14747-15887      + | ENST00000361789
#   ENST00000361851 GRCh38_chrMT     8366-8572      + | ENST00000361851
#   ENST00000361899 GRCh38_chrMT     8527-9207      + | ENST00000361899
#   ENST00000362079 GRCh38_chrMT     9207-9990      + | ENST00000362079
#                     gene_name         gene_id   gene_biotype     type
#                   <character>     <character>    <character> <factor>
#   ENSE00001489430      PLCXD1 ENSG00000182378 protein_coding     exon
#   ENSE00001536003      PLCXD1 ENSG00000182378 protein_coding     exon
#   ENSE00002160563      PLCXD1 ENSG00000182378 protein_coding     exon
#   ENSE00001750899      PLCXD1 ENSG00000182378 protein_coding     exon
#   ENSE00001489388      PLCXD1 ENSG00000182378 protein_coding     exon
#               ...         ...             ...            ...      ...
#   ENST00000361739      MT-CO2 ENSG00000198712 protein_coding      cds
#   ENST00000361789      MT-CYB ENSG00000198727 protein_coding      cds
#   ENST00000361851     MT-ATP8 ENSG00000228253 protein_coding      cds
#   ENST00000361899     MT-ATP6 ENSG00000198899 protein_coding      cds
#   ENST00000362079      MT-CO3 ENSG00000198938 protein_coding      cds
#   -------
#   seqinfo: 47 sequences from 2 genomes (mm10, hg38)

# %%
Reduce(merge, l3)
# Out:
# Warning message in FUN(X[[i]], ...):
# "Some of the objects to merge contain duplicated elements. These
#   elements were removed by applying unique() to each object before the
#   merging."
# Warning message in FUN(X[[i]], ...):
# "Some of the objects to merge contain duplicated elements. These
#   elements were removed by applying unique() to each object before the
#   merging."
# GRanges object with 0 ranges and 5 metadata columns:
#    seqnames    ranges strand |       tx_id   gene_name     gene_id gene_biotype
#       <Rle> <IRanges>  <Rle> | <character> <character> <character>  <character>
#        type
#    <factor>
#   -------
#   seqinfo: 47 sequences from 2 genomes (mm10, hg38)

# %%
unlist(as(l3, "GRangesList"))
# Out:
# GRanges object with 4785116 ranges and 5 metadata columns:
#                          seqnames          ranges strand |              tx_id
#                             <Rle>       <IRanges>  <Rle> |        <character>
#   ENSMUSE00001236884    mm10_chr3 3508030-3508332      + | ENSMUST00000108393
#   ENSMUSE00000676606    mm10_chr3 3634150-3634347      + | ENSMUST00000108394
#   ENSMUSE00001345708    mm10_chr3 3638059-3638230      + | ENSMUST00000108393
#   ENSMUSE00001345708    mm10_chr3 3638059-3638230      + | ENSMUST00000108394
#   ENSMUSE00000149313    mm10_chr3 3641223-3641317      + | ENSMUST00000108393
#                  ...          ...             ...    ... .                ...
#      ENST00000361739 GRCh38_chrMT       7586-8269      + |    ENST00000361739
#      ENST00000361789 GRCh38_chrMT     14747-15887      + |    ENST00000361789
#      ENST00000361851 GRCh38_chrMT       8366-8572      + |    ENST00000361851
#      ENST00000361899 GRCh38_chrMT       8527-9207      + |    ENST00000361899
#      ENST00000362079 GRCh38_chrMT       9207-9990      + |    ENST00000362079
#                        gene_name            gene_id   gene_biotype     type
#                      <character>        <character>    <character> <factor>
#   ENSMUSE00001236884       Hnf4g ENSMUSG00000017688 protein_coding     exon
#   ENSMUSE00000676606       Hnf4g ENSMUSG00000017688 protein_coding     exon
#   ENSMUSE00001345708       Hnf4g ENSMUSG00000017688 protein_coding     exon
#   ENSMUSE00001345708       Hnf4g ENSMUSG00000017688 protein_coding     exon
#   ENSMUSE00000149313       Hnf4g ENSMUSG00000017688 protein_coding     exon
#                  ...         ...                ...            ...      ...
#      ENST00000361739      MT-CO2    ENSG00000198712 protein_coding      cds
#      ENST00000361789      MT-CYB    ENSG00000198727 protein_coding      cds
#      ENST00000361851     MT-ATP8    ENSG00000228253 protein_coding      cds
#      ENST00000361899     MT-ATP6    ENSG00000198899 protein_coding      cds
#      ENST00000362079      MT-CO3    ENSG00000198938 protein_coding      cds
#   -------
#   seqinfo: 47 sequences from 2 genomes (mm10, hg38)

# %%
GenomicRanges::merge(annotations, annotations1, all=T)
# Out:
# Warning message in FUN(X[[i]], ...):
# "Some of the objects to merge contain duplicated elements. These
#   elements were removed by applying unique() to each object before the
#   merging."
# Warning message in FUN(X[[i]], ...):
# "Some of the objects to merge contain duplicated elements. These
#   elements were removed by applying unique() to each object before the
#   merging."
# Warning message in .Seqinfo.mergexy(x, y):
# "The 2 combined objects have no sequence levels in common. (Use
#   suppressWarnings() to suppress this warning.)"
# GRanges object with 1693971 ranges and 5 metadata columns:
#                          seqnames          ranges strand |              tx_id
#                             <Rle>       <IRanges>  <Rle> |        <character>
#   ENSMUST00000108393    mm10_chr3 3508030-3508328      + | ENSMUST00000108393
#   ENSMUSE00001236884    mm10_chr3 3508030-3508332      + | ENSMUST00000108393
#   ENSMUST00000108393    mm10_chr3 3508329-3508332      + | ENSMUST00000108393
#   ENSMUST00000108394    mm10_chr3 3634150-3634211      + | ENSMUST00000108394
#   ENSMUSE00000676606    mm10_chr3 3634150-3634347      + | ENSMUST00000108394
#                  ...          ...             ...    ... .                ...
#      ENSE00001596097 GRCh38_chrMT     10470-10766      + |    ENST00000361335
#      ENSE00001666004 GRCh38_chrMT     10760-12137      + |    ENST00000361381
#      ENSE00001435330 GRCh38_chrMT     12337-14148      + |    ENST00000361567
#      ENSE00001436074 GRCh38_chrMT     14747-15887      + |    ENST00000361789
#      ENSE00001434974 GRCh38_chrMT     14149-14673      - |    ENST00000361681
#                        gene_name            gene_id   gene_biotype     type
#                      <character>        <character>    <character> <factor>
#   ENSMUST00000108393       Hnf4g ENSMUSG00000017688 protein_coding     utr
#   ENSMUSE00001236884       Hnf4g ENSMUSG00000017688 protein_coding     exon
#   ENSMUST00000108393       Hnf4g ENSMUSG00000017688 protein_coding     cds
#   ENSMUST00000108394       Hnf4g ENSMUSG00000017688 protein_coding     utr
#   ENSMUSE00000676606       Hnf4g ENSMUSG00000017688 protein_coding     exon
#                  ...         ...                ...            ...      ...
#      ENSE00001596097     MT-ND4L    ENSG00000212907 protein_coding     exon
#      ENSE00001666004      MT-ND4    ENSG00000198886 protein_coding     exon
#      ENSE00001435330      MT-ND5    ENSG00000198786 protein_coding     exon
#      ENSE00001436074      MT-CYB    ENSG00000198727 protein_coding     exon
#      ENSE00001434974      MT-ND6    ENSG00000198695 protein_coding     exon
#   -------
#   seqinfo: 47 sequences from 2 genomes (mm10, hg38)

# %%
# add the gene information to the object
Annotation(brain) <- annotations

# %%
brain <- NucleosomeSignal(object = brain)

# %%
brain <- TSSEnrichment(brain, fast = FALSE)
# Out:
# Extracting TSS positions
#
# Finding + strand cut sites
#
# Finding - strand cut sites
#
# Computing mean insertion frequency in flanking regions
#
# Normalizing TSS score

# %%
brain$high.tss <- ifelse(brain$TSS.enrichment > 2, 'High', 'Low')
TSSPlot(brain, group.by = 'high.tss') + NoLegend() + ggtitle("Enrichment around TSS")
# Out:
# plot without title

# %%
TSSPlot(brain) + NoLegend() + ggtitle("Enrichment around TSS")
# Out:
# plot without title

# %%
df = as.data.frame(brain@assays$peaks@positionEnrichment)

# %%
max(colMeans(df))

# %%
?TSSEnrichment

# %%
?TSSPlot

# %%
df
