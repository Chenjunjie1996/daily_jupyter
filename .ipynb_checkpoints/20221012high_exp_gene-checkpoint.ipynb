# %%
import numpy as np
import pandas as pd
import scanpy as sc
import seaborn as sns 

sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.settings.set_figure_params(dpi=80)
sc.logging.print_versions()

# %%
sample = sc.read_h5ad('/SGRNJ03/randd/RD20081702_SCOPEv2_slide_RT/20220421/Control_M_0303/06.analysis/Control_M_0303.h5ad')

# %%
sample
# Out:
# AnnData object with n_obs × n_vars = 9849 × 25221
#     obs: 'n_genes_by_counts', 'total_counts', 'total_counts_mito', 'pct_counts_mito', 'cluster'
#     var: 'gene_ids', 'mito', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'hvg', 'leiden', 'neighbors', 'pca', 'rank_genes_groups', 'tsne', 'umap'
#     obsm: 'X_pca', 'X_tsne', 'X_umap'
#     varm: 'PCs'
#     layers: 'normalised'
#     obsp: 'connectivities', 'distances'

# %%
sample.var.sort_values('total_counts',ascending=False).head(50).to_csv('/SGRNJ06/randd/USER/cjj/celedev/wanyue/20221012high_exp_gene/Control_M_0303.tsv', sep='\t')

# %%
sample.obs
# Out:
#                           n_genes_by_counts  total_counts  total_counts_mito  \
# AAACATCGAAACATCGCGCATACA               1049        2783.0               15.0
# AAACATCGAACAACCAAGTGGTCA               1735        5705.0               36.0
# AAACATCGAACCGAGAAACAACCA               1159        3923.0               75.0
# AAACATCGAACGCTTAAACCGAGA                724        1723.0               40.0
# AAACATCGAACGCTTAACACGACC               1109        2922.0               18.0
# ...                                     ...           ...                ...
# TTCACGCAGTCTGTCAGATAGACA                374         773.0                3.0
# TTCACGCATCCGTCTACGACTGGA                789       10938.0               27.0
# TTCACGCATCTTCACACAGATCTG               1652        5087.0               18.0
# TTCACGCATGAAGAGATCTTCACA               2885       14751.0               88.0
# TTCACGCATGGCTTCACTGGCATA                937        2217.0               22.0
#
# ...

# %%
adata = sc.read_10x_mtx("/SGRNJ03/randd/RD20081702_SCOPEv2_slide_RT/20220314/FUT10_0302/05.count/FUT10_0302_matrix_10X", var_names="gene_symbols")
# Out:
# --> This might be very slow. Consider passing `cache=True`, which enables much faster reading from a cache file.

# %%
adata.var_names
# Out:
# Index(['Gnai3', 'Cdc45', 'Scml2', 'Narf', 'Cav2', 'Klf6', 'Scmh1', 'Cox5a',
#        'Tbx2', 'Ngfr',
#        ...
#        'CT033751.1', 'AC147041.2', 'AC139513.1', 'AC169509.5', 'AL592187.7',
#        'AC126682.1', 'AC161165.5', 'AC123724.3', 'AC161165.6', 'AL591952.3'],
#       dtype='object', length=20181)

# %%
adata.var["mito"] = adata.var_names.str.upper().str.startswith('MT-')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 6230 × 20181
#     var: 'gene_ids', 'mito'

# %%
        sc.pp.calculate_qc_metrics(
            adata,
            qc_vars=["mito"], 
            percent_top=None,
            use_raw=False,
            log1p=False, 
            inplace=True
        )

# %%
adata.var.sort_values('total_counts',ascending=False).head(50).to_csv("/SGRNJ06/randd/USER/cjj/celedev/wanyue/20221012high_exp_gene/FUT20.tsv",sep="\t")

# %%
# sc.pl.highest_expr_genes(adata, n_top=20)
# Out:
# normalizing counts per cell
#     finished (0:00:00)
