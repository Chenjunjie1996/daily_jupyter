# %%
library(Seurat)
library(tidyverse)
# Out:
# Warning message:
# “package ‘Seurat’ was built under R version 4.0.5”
# Attaching SeuratObject
#
# Registered S3 method overwritten by 'cli':
#   method     from
#   print.boxx spatstat.geom
#
# ── Attaching packages ────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.3     ✔ purrr   0.3.4
# ✔ tibble  3.1.0     ✔ dplyr   1.0.5
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ───────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
rds = readRDS("/SGRNJ06/randd/PROJECT/RD20073101_ScRNA_VDJ/2022_cm/20230512_MHmix/amulti/rds_.diff_PRO.rds")

# %%
meta = rds@meta.data

# %%
meta
# Out:
#                                            orig.ident        nCount_RNA
# HM2_1_Nlib_AAACATCGAACAACCAAAGAGATC        HM2_1_Nlib        1012
# HM2_1_Nlib_AAACATCGAACCGAGAAAACATCG        HM2_1_Nlib        4722
# HM2_1_Nlib_AAACATCGAACCGAGAACCACTGT        HM2_1_Nlib         787
# HM2_1_Nlib_AAACATCGAACCGAGACGACTGGA        HM2_1_Nlib        1449
# HM2_1_Nlib_AAACATCGAACGCTTACAGCGTTA        HM2_1_Nlib        1626
# HM2_1_Nlib_AAACATCGAAGACGGACTCAATGA        HM2_1_Nlib        1611
# HM2_1_Nlib_AAACATCGAAGAGATCCAAGGAGC        HM2_1_Nlib        1758
# HM2_1_Nlib_AAACATCGAAGGACACCTGTAGCC        HM2_1_Nlib        1402
# HM2_1_Nlib_AAACATCGAATCCGTCCATACCAA        HM2_1_Nlib        1896
# HM2_1_Nlib_AAACATCGAATCCGTCTAGGATGA        HM2_1_Nlib        2613
# HM2_1_Nlib_AAACATCGAATGTTGCTAGGATGA        HM2_1_Nlib         666
# HM2_1_Nlib_AAACATCGACAAGCTATGAAGAGA        HM2_1_Nlib        1455
# HM2_1_Nlib_AAACATCGACACAGAACATCAAGT        HM2_1_Nlib        1261
# ...

# %%
write.table(meta,"/SGRNJ06/randd/USER/cjj/celedev/rna/20230516hs_mu/meta.tsv",sep='\t',quote=F,row.names=T)

# %%
# PYTHON
import pandas as pd

# %%
df = pd.read_csv("/SGRNJ06/randd/USER/cjj/celedev/rna/20230516hs_mu/meta.tsv", sep='\t')

# %%
df.index = [i.split('_')[-1] for i in df.index]

# %%
df.seurat_clusters.value_counts()
# Out:
# 0     12502
# 1      8267
# 2      7929
# 3      4510
# 4      4036
# 5      3091
# 6      2859
# 7      2288
# 8      2069
# 9      1736
# 10     1709
# 11     1573
# 12     1532
# 13     1337
# 14     1312
# 15     1222
# 16     1162
# 17      991
# 18      874
# 19      821
# 20      577
# 21      387
# 22      383
# 23      294
# 24      272
# 25      185
# 26       66
# Name: seurat_clusters, dtype: int64

# %%
df_mu = df[df.seurat_clusters.isin([0,1,2,3,4,5,6,8,9,11,12,13,14,16,17,18,21,22,23,24,25,26])]
df_hs = df[df.seurat_clusters.isin([7,10,15,19,20])]

# %%
df["orig.ident"].value_counts()
# Out:
# HM3_1_Nlib           13308
# HM3_2_Nlib           13232
# HM2_2_Nlib           10307
# HM2_1_Nlib           10166
# RTmix_0506_2_Nlib     9680
# RTmix_0506_1_Nlib     7291
# Name: orig.ident, dtype: int64

# %%
df_mu_HM2_1_Nlib = df_mu[df_mu["orig.ident"].isin(["HM2_1_Nlib"])]
df_hs_HM2_1_Nlib = df_hs[df_hs["orig.ident"].isin(["HM2_1_Nlib"])]

df_mu_HM2_2_Nlib = df_mu[df_mu["orig.ident"].isin(["HM2_2_Nlib"])]
df_hs_HM2_2_Nlib = df_hs[df_hs["orig.ident"].isin(["HM2_2_Nlib"])]

df_mu_HM3_1_Nlib = df_mu[df_mu["orig.ident"].isin(["HM3_1_Nlib"])]
df_hs_HM3_1_Nlib = df_hs[df_hs["orig.ident"].isin(["HM3_1_Nlib"])]

df_mu_HM3_2_Nlib = df_mu[df_mu["orig.ident"].isin(["HM3_2_Nlib"])]
df_hs_HM3_2_Nlib = df_hs[df_hs["orig.ident"].isin(["HM3_2_Nlib"])]

df_mu_RTmix_0506_1_Nlib = df_mu[df_mu["orig.ident"].isin(["RTmix_0506_1_Nlib"])]
df_hs_RTmix_0506_1_Nlib = df_hs[df_hs["orig.ident"].isin(["RTmix_0506_1_Nlib"])]

df_mu_RTmix_0506_2_Nlib = df_mu[df_mu["orig.ident"].isin(["RTmix_0506_2_Nlib"])]
df_hs_RTmix_0506_2_Nlib = df_hs[df_hs["orig.ident"].isin(["RTmix_0506_2_Nlib"])]

# %%
with open("/SGRNJ06/randd/USER/cjj/celedev/rna/20230516hs_mu/HM2_1_Nlib_hs/05.count/HM2_1_Nlib_matrix_10X/barcodes.tsv", 'w') as f:
    for i in list(df_hs_HM2_1_Nlib.index):
        f.write(f"{i}\n")
with open("/SGRNJ06/randd/USER/cjj/celedev/rna/20230516hs_mu/HM2_1_Nlib_mu/05.count/HM2_1_Nlib_matrix_10X/barcodes.tsv", 'w') as f:
    for i in list(df_mu_HM2_1_Nlib.index):
        f.write(f"{i}\n")
        
with open("/SGRNJ06/randd/USER/cjj/celedev/rna/20230516hs_mu/HM2_2_Nlib_hs/05.count/HM2_2_Nlib_matrix_10X/barcodes.tsv", 'w') as f:
    for i in list(df_hs_HM2_2_Nlib.index):
        f.write(f"{i}\n")
with open("/SGRNJ06/randd/USER/cjj/celedev/rna/20230516hs_mu/HM2_2_Nlib_mu/05.count/HM2_2_Nlib_matrix_10X/barcodes.tsv", 'w') as f:
    for i in list(df_mu_HM2_2_Nlib.index):
        f.write(f"{i}\n")

with open("/SGRNJ06/randd/USER/cjj/celedev/rna/20230516hs_mu/HM3_1_Nlib_hs/05.count/HM3_1_Nlib_matrix_10X/barcodes.tsv", 'w') as f:
    for i in list(df_hs_HM3_1_Nlib.index):
        f.write(f"{i}\n")
with open("/SGRNJ06/randd/USER/cjj/celedev/rna/20230516hs_mu/HM3_1_Nlib_mu/05.count/HM3_1_Nlib_matrix_10X/barcodes.tsv", 'w') as f:
    for i in list(df_mu_HM3_1_Nlib.index):
        f.write(f"{i}\n")

with open("/SGRNJ06/randd/USER/cjj/celedev/rna/20230516hs_mu/HM3_2_Nlib_hs/05.count/HM3_2_Nlib_matrix_10X/barcodes.tsv", 'w') as f:
    for i in list(df_hs_HM3_2_Nlib.index):
        f.write(f"{i}\n")
with open("/SGRNJ06/randd/USER/cjj/celedev/rna/20230516hs_mu/HM3_2_Nlib_mu/05.count/HM3_2_Nlib_matrix_10X/barcodes.tsv", 'w') as f:
    for i in list(df_mu_HM3_2_Nlib.index):
        f.write(f"{i}\n")

with open("/SGRNJ06/randd/USER/cjj/celedev/rna/20230516hs_mu/RTmix_0506_1_Nlib_hs/05.count/RTmix_0506_1_Nlib_matrix_10X/barcodes.tsv", 'w') as f:
    for i in list(df_hs_RTmix_0506_1_Nlib.index):
        f.write(f"{i}\n")
with open("/SGRNJ06/randd/USER/cjj/celedev/rna/20230516hs_mu/RTmix_0506_1_Nlib_mu/05.count/RTmix_0506_1_Nlib_matrix_10X/barcodes.tsv", 'w') as f:
    for i in list(df_mu_RTmix_0506_1_Nlib.index):
        f.write(f"{i}\n")
        
with open("/SGRNJ06/randd/USER/cjj/celedev/rna/20230516hs_mu/RTmix_0506_2_Nlib_hs/05.count/RTmix_0506_2_Nlib_matrix_10X/barcodes.tsv", 'w') as f:
    for i in list(df_hs_RTmix_0506_2_Nlib.index):
        f.write(f"{i}\n")
with open("/SGRNJ06/randd/USER/cjj/celedev/rna/20230516hs_mu/RTmix_0506_2_Nlib_mu/05.count/RTmix_0506_2_Nlib_matrix_10X/barcodes.tsv", 'w') as f:
    for i in list(df_mu_RTmix_0506_2_Nlib.index):
        f.write(f"{i}\n")

# %%
import glob

# %%
glob.glob("/SGRNJ06/randd/USER/cjj/celedev/rna/20230407hs_mu/*/*/*/*/barcodes.tsv")

# %%
library(Seurat)

# %%
RAW1 <- Read10X("/SGRNJ06/randd/PROJECT/RD20073101_ScRNA_VDJ/2022_cm/20230512_MHmix/HM2_2_Nlib/05.count/HM2_2_Nlib_filtered_feature_bc_matrix")

# %%
RAW1
